# %% [markdown]
# # Machine Learning II
# ## Urban Sound Classification: Deep Learning Approaches for Audio Recognition
# #### Work assembled by Aligga Goncigga, Francigga Niggalache, Alexigga Luskigga

# %% [markdown]
# ### Table of contents <a name="contents"></a>
# 1. [Introduction](#introduction)
# 2. [Data Understanding](#data-understanding)
# 3. [Data Reading](#data-reading)
#     - 3.1. [Feature Extraction](#feature-extraction)
#     - 3.2. [Data Cleaning](#data-cleaning)
#
#       - 3.2.1. [Reading](#reading)
#
#       - 3.2.2. [Cleaning](#cleaning)
# 5. [Classifiers](#classifiers)
#
#    - 4.1. [Multilayer Perceptron (MLP)](#multilayer)
#    - 4.2. [Convolutional neural network (CNN)](#convolutional)

# %% [markdown]
# ## Introduction <a name="introduction"></a>
# [[go back to the top]](#contents)
#
# The objective of this project is to develop **deep learning classifiers** for urban sound data. In this assignment, we will implement two of the three classifiers provided by the professor, as outlined in the [[PDF]](./Project.pdf).
#
# The classifiers are:
#
# • A classifier based on a multilayer perceptron (MLP)
#
# • A classifier based on a convolutional neural network (CNN)
#
# • A classifier based on a recurrent neural network (RNN)
#
# And for each of the chosen classifier, the implementation will need to consider the following steps:
# 1. Data pre-processing and preparation
# 2. Model architecture definition
# 3. Training strategies
# 4. Performance evaluation

# %% [markdown]
# ## Data Understanding <a name="data-understanding"></a>
# [[go back to the top]](#contents)

# %% [markdown]
# The dataset consists of 8,732 labeled sound excerpts, each lasting up to 4 seconds, categorized into 10 distinct classes:
# - air_conditioner [0]
# - car_horn [1]
# - children_playing [2]
# - dog_bark [3]
# - drilling [4]
# - enginge_idling [5]
# - gun_shot [6]
# - jackhammer [7]
# - siren [8]
# - street_music [9]

# %% [markdown]
# The sound classes in the UrbanSound and UrbanSound8K datasets are derived from the UrbanSound taxonomy, as presented on the https://urbansounddataset.weebly.com/taxonomy.html
#
# Below is an image showcasing the taxonomy structure from the referenced site:

# %% [markdown]
# ![Descrição da imagem](./taxonomy.png)

# %% [markdown]
# All audio excerpts are derived from field recordings uploaded to http://www.freesound.org/
#
# The dataset comprises 8,732 urban sound audio files in WAV format. The sampling rate, bit depth, and number of channels correspond to those of the original files uploaded to Freesound, which may vary across different recordings.
#
# In addition to the audio excerpts, a CSV file containing metadata for each excerpt is also included.
#
# This is a short explanation of the csv:
#
# | Name of the Column | Brief Explanation                                                                                       |
# |--------------------|--------------------------------------------------------------------------------------------------------|
# | slice_file_name    | The name of the audio file, formatted as [fsID]-[classID]-[occurrenceID]-[sliceID].wav.              |
# | fsID               | The Freesound ID of the recording from which this excerpt (slice) is taken.                           |
# | start              | The start time of the slice in the original Freesound recording.                                      |
# | end                | The end time of the slice in the original Freesound recording.                                        |
# | salience           | A subjective salience rating of the sound (1 = foreground, 2 = background).                           |
# | fold               | The fold number (1-10) to which this file has been allocated.                                         |
# | classID            | A numeric identifier of the sound class (0-9) as listed above.                                        |
# | [occurrenceID]     | A numeric identifier to distinguish different occurrences of the sound within the original recording. |
# | [sliceID]          | A numeric identifier to distinguish different slices taken from the same occurrence.                 |

# %% [markdown]
# **To avoid common pitfalls**:
# -  Don't reshuffle the data! Use the predefined 10 folds and perform 10-fold (not 5-fold) cross validation
# -  Don't evaluate just on one split! Use 10-fold (not 5-fold) cross validation and average the scores

# %% [markdown]
# ## Data Reading <a name="data-reading"></a>
# [[go back to the top]](#contents)
#
#
# After carefully analyzing the three available classifiers, we decided to implement MLP and CNN for this project. Our decision was based on several important considerations, which we have outlined in detail in the following [[Notes]](./Notas.md).
#
# Let's explore what we have and outline what we'll be working on in the coming days.

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import librosa
import os
import numpy as np
import soundfile as sf
from sklearn.preprocessing import MinMaxScaler
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt
import librosa.display
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
path_csv = 'UrbanSound8K/metadata/UrbanSound8K.csv'

df = pd.read_csv(path_csv)

print(df.head())
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3  \
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %% [markdown]
# ##### Check if there's any missing values

# %%
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# slice_file_name    0
# fsID               0
# start              0
# end                0
# salience           0
# fold               0
# classID            0
# class              0
# dtype: int64

# %% [markdown]
# ##### Visualizing graphically

# %%
ax = sns.histplot(y='class',data = df, hue="class", multiple="stack")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xticks(rotation=45)
sns.despine()
plt.show()

# %%
class_dict = df['class'].value_counts(normalize=True)
classes = list(np.unique(df['class']))
fig, ax = plt.subplots()
ax.set_title('Class Distribution', y=1.08, fontsize=18)
ax.pie(class_dict, labels=classes, autopct='%1.1f%%', shadow=False, startangle=180)
ax.axis('equal')
plt.savefig("distribution_class")
plt.show(block=False)

# %% [markdown]
# ##### Accessing the audio data

# %%
# Path to the folder where the audio dubs are located
base_path = 'UrbanSound8K/audio'

# Go through the 10 folds
for fold in range(1, 11):
    fold_path = os.path.join(base_path, f'fold{fold}')
    
    # Check if the folder path exists
    if os.path.exists(fold_path):
        # Browse the audio files within the fold
        for file_name in os.listdir(fold_path):
            if file_name.endswith('.wav'):
                # Full path to the audio file
                file_path = os.path.join(fold_path, file_name)
                
                # Upload audio using librosa
                audio, sample_rate = librosa.load(file_path)
                
                # Example: Process audio or extract features
                print(f"File: {file_name}, Sample Rate: {sample_rate}, Duration: {len(audio)/sample_rate:.2f}s")
# Out:
# File: 135776-2-0-49.wav, Sample Rate: 22050, Duration: 4.00s
# File: 46654-6-0-0.wav, Sample Rate: 22050, Duration: 1.14s
# File: 57320-0-0-24.wav, Sample Rate: 22050, Duration: 4.00s
# File: 134717-0-0-26.wav, Sample Rate: 22050, Duration: 4.00s
# File: 174276-7-5-0.wav, Sample Rate: 22050, Duration: 2.87s
# File: 180937-7-2-6.wav, Sample Rate: 22050, Duration: 4.00s
# File: 17913-4-0-1.wav, Sample Rate: 22050, Duration: 4.00s
# File: 103074-7-4-6.wav, Sample Rate: 22050, Duration: 4.00s
# File: 176787-5-0-9.wav, Sample Rate: 22050, Duration: 4.00s
# File: 55020-4-0-11.wav, Sample Rate: 22050, Duration: 4.00s
# File: 138015-3-0-7.wav, Sample Rate: 22050, Duration: 4.00s
# File: 180937-7-0-4.wav, Sample Rate: 22050, Duration: 4.00s
# File: 180937-7-1-13.wav, Sample Rate: 22050, Duration: 4.00s
# File: 157867-8-0-10.wav, Sample Rate: 22050, Duration: 4.00s
# File: 103074-7-2-0.wav, Sample Rate: 22050, Duration: 1.38s
# File: 113205-5-1-4.wav, Sample Rate: 22050, Duration: 4.00s
# File: 57584-4-0-8.wav, Sample Rate: 22050, Duration: 4.00s
# File: 118279-8-0-8.wav, Sample Rate: 22050, Duration: 4.00s
# File: 137156-9-0-73.wav, Sample Rate: 22050, Duration: 4.00s
# File: 165645-4-1-0.wav, Sample Rate: 22050, Duration: 0.88s
# File: 182800-2-2-0.wav, Sample Rate: 22050, Duration: 4.00s
# File: 
1.wav, Sample Rate: 22050, Duration: 4.00s
# File: 165166-8-0-5.wav, Sample Rate: 22050, Duration: 4.00s
# File: 118558-5-2-1.wav, Sample Rate: 22050, Duration: 4.00s
# File: 178826-2-0-17.wav, Sample Rate: 22050, Duration: 4.00s
# File: 73524-0-0-105.wav, Sample Rate: 22050, Duration: 4.00s
# File: 136558-9-1-21.wav, Sample Rate: 22050, Duration: 4.00s
# File: 93567-8-0-13.wav, Sample Rate: 22050, Duration: 4.00s
# File: 88121-8-0-0.wav, Sample Rate: 22050, Duration: 4.00s
# File: 189982-0-0-42.wav, Sample Rate: 22050, Duration: 4.00s
# File: 74364-8-1-7.wav, Sample Rate: 22050, Duration: 4.00s
# File: 99192-4-0-7.wav, Sample Rate: 22050, Duration: 4.00s
# File: 101382-2-0-33.wav, Sample Rate: 22050, Duration: 4.00s

# %% [markdown]
# ##### As observed, some audio clips have varying durations, such as 1.64, 2.61, and up to 4 seconds. To simplify the processing and ensure consistency, we will standardize all audio data to the same length. This allows for uniform input to our models, improving training efficiency and performance. How can we do that?

# %% [markdown]
# ##### Well, there's four strategies:
# - **Zeropadding:** Ideal for maintaining the integrity of short audios.
# - **Audio Repetition:** Works well for rhythmic or repetitive sounds.
# - **Discard Short Audios:** Simple and effective when you can afford to lose some data.
# - **Interpolation:** Suitable if you want to maintain consistency in the timing of the audio, but can change the way it sounds.
#
# Although we already thought and started with an approach (Zeropadding), we had a conversation with the teacher about what would be the best strategy to perform, and we came with the conclusion that **Audio Repetition** would be the best.

# %% [markdown]
# ##### Audio Repetition

# %%
# Target duration and sample rate
target_duration = 4.0  # seconds
sample_rate = 22050  # sample rate

# Path to the folder where the audio files are located
base_path = 'UrbanSound8K/audio'

# Loop through the 10 folds
for fold in range(1, 11):
    fold_path = os.path.join(base_path, f'fold{fold}')
    
    # Check if the folder path exists
    if os.path.exists(fold_path):
        print(f"\nProcessing files in {fold_path}...")
        
        # Loop through the audio files within the fold
        for file_name in os.listdir(fold_path):
            if file_name.endswith('.wav'):
                # Full path to the audio file
                file_path = os.path.join(fold_path, file_name)
                
                # Load audio with librosa
                audio, sr = librosa.load(file_path, sr=sample_rate)
                
                # Check if the audio is shorter than the target duration
                if len(audio) < target_duration * sample_rate:
                    # Calculate the number of samples required
                    target_samples = int(target_duration * sample_rate)
                    audio_repeated = np.tile(audio, int(np.ceil(target_samples / len(audio))))
                    audio_repeated = audio_repeated[:target_samples]
                else:
                    audio_repeated = audio
                
                # Save the adjusted audio, replacing the original (or in a new directory)
                sf.write(file_path, audio_repeated, sample_rate)
                print(f"File {file_name} processed with duration of {target_duration} seconds.")
# Out:
# Processing files in UrbanSound8K/audio/fold1...
# File 135776-2-0-49.wav processed with duration of 4.0 seconds.
# File 46654-6-0-0.wav processed with duration of 4.0 seconds.
# File 57320-0-0-24.wav processed with duration of 4.0 seconds.
# File 134717-0-0-26.wav processed with duration of 4.0 seconds.
# File 174276-7-5-0.wav processed with duration of 4.0 seconds.
# File 180937-7-2-6.wav processed with duration of 4.0 seconds.
# File 17913-4-0-1.wav processed with duration of 4.0 seconds.
# File 103074-7-4-6.wav processed with duration of 4.0 seconds.
# File 176787-5-0-9.wav processed with duration of 4.0 seconds.
# File 55020-4-0-11.wav processed with duration of 4.0 seconds.
# File 138015-3-0-7.wav processed with duration of 4.0 seconds.
# File 180937-7-0-4.wav processed with duration of 4.0 seconds.
# File 180937-7-1-13.wav processed with duration of 4.0 seconds.
# File 157867-8-0-10.wav processed with duration of 4.0 seconds.
# File 103074-7-2-0.wav processed with duration of 4.0 seconds.
# File 113205-5-1-4.wav processed with duration of 4.0 seconds.
# File 57584-4-0-8.wav processed with duration of 4.0 seconds.
# File 118279-8-0-8.wav processed with duration of 4.0 seconds.
# File 137156-9-0-73.wav processed with duration of 4.0 seconds.
# File 165645-4-1-0.wav processed with duration of 4.0 seconds.
# File 182800-2-2-0.wav processed with duration of 4.0 seconds.
# File 103074-7-0-2.wav processed with duration of 4.0 seconds.
# File 159738-8-0-1.wav processed with duration of 4.0 seconds.
# File 180937-7-4-0.wav processed with duration of 4.0 seconds.
# File 164053-8-1-0.wav processed with duration of 4.0 seconds.
# File 159738-8-0-0.wav processed with duration of 4.0 seconds.
# File 132016-9-0-11.wav processed with duration of 4.0 seconds.
# File 182800-2-2-1.wav processed with duration of 4.0 seconds.
# File 180937-7-3-17.wav processed with duration of 4.0 seconds.
# File 125791-3-0-9.wav processed with duration of 4.0 seconds.
# File 108041-9-0-9.wav processed with duration of 4.0 seconds.
# File 197318-6-1-0.wav processed with duration of 4.0 seconds.
# File 118279-8-0-9.wav processed with duration of 4.0 seconds.
# File 191431-9-0-8.wav processed with duration of 4.0 seconds.
# File 139951-9-0-33.wav processed with duration of 4.0 seconds.
# File 113205-5-1-5.wav processed with duration of 4.0 seconds.
# File 180937-7-1-12.wav processed with duration of 4.0 seconds.
# File 180937-7-0-5.wav processed with duration of 4.0 seconds.
# File 157867-8-0-11.wav processed with duration of 4.0 seconds.
# File 99180-9-0-7.wav processed with duration of 4.0 seconds.
# File 176787-5-0-8.wav processed with duration of 4.0 seconds.
# File 55020-4-0-10.wav processed with duration of 4.0 seconds.
# File 192124-2-0-0.wav processed with duration of 4.0 seconds.
# File 98223-7-1-0.wav processed with duration of 4.0 seconds.
# File 17913-4-0-0.wav processed with duration of 4.0 seconds.
# File 134717-0-0-27.wav processed with duration of 4.0 seconds.
# File 72261-3-0-23.wav processed with duration of 4.0 seconds.
# File 180937-7-2-7.wav processed with duration of 4.0 seconds.
# File 143651-2-0-0.wav processed with duration of 4.0 seconds.
# File 57320-0-0-31.wav processed with duration of 4.0 seconds.
# File 54858-3-1-2.wav processed with duration of 4.0 seconds.
# File 98223-7-3-0.wav processed with duration of 4.0 seconds.
# File 17913-4-2-0.wav processed with duration of 4.0 seconds.
# File 97317-2-0-28.wav processed with duration of 4.0 seconds.
# File 134717-0-0-19.wav processed with duration of 4.0 seconds.
# File 197073-3-4-3.wav processed with duration of 4.0 seconds.
# File 57320-0-0-33.wav processed with duration of 4.0 seconds.
# File 180937-7-2-5.wav processed with duration of 4.0 seconds.
# File 134717-0-0-25.wav processed with duration of 4.0 seconds.
# File 57320-0-0-27.wav processed with duration of 4.0 seconds.
# File 103074-7-4-5.wav processed with duration of 4.0 seconds.
# File 17913-4-0-2.wav processed with duration of 4.0 seconds.
# File 51022-3-29-0.wav processed with duration of 4.0 seconds.
# File 55020-4-0-9.wav processed with duration of 4.0 seconds.
# File 157867-8-0-13.wav processed with duration of 4.0 seconds.
# File 180937-7-1-10.wav processed with duration of 4.0 seconds.
# File 55020-4-0-12.wav processed with duration of 4.0 seconds.
# File 113205-5-1-7.wav processed with duration of 4.0 seconds.
# File 9031-3-4-0.wav processed with duration of 4.0 seconds.
# File 143651-2-0-16.wav processed with duration of 4.0 seconds.
# File 180937-7-3-29.wav processed with duration of 4.0 seconds.
# File 180937-7-3-15.wav processed with duration of 4.0 seconds.
# File 182800-2-2-3.wav processed with duration of 4.0 seconds.
# File 103074-7-0-1.wav processed with duration of 4.0 seconds.
# File 159738-8-0-2.wav processed with duration of 4.0 seconds.
# File 197318-6-3-0.wav processed with duration of 4.0 seconds.
# File 194732-9-0-191.wav processed with duration of 4.0 seconds.
# File 180937-7-4-3.wav processed with duration of 4.0 seconds.
# File 105415-2-0-8.wav processed with duration of 4.0 seconds.
# File 180937-7-4-2.wav processed with duration of 4.0 seconds.
# File 165645-4-3-0.wav processed with duration of 4.0 seconds.
# File 159738-8-0-3.wav processed with duration of 4.0 seconds.
# File 155310-3-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-0-0.wav processed with duration of 4.0 seconds.
# File 182800-2-2-2.wav processed with duration of 4.0 seconds.
# File 147764-4-8-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-14.wav processed with duration of 4.0 seconds.
# File 164053-8-3-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-28.wav processed with duration of 4.0 seconds.
# File 113205-5-1-6.wav processed with duration of 4.0 seconds.
# File 182800-2-0-0.wav processed with duration of 4.0 seconds.
# File 26270-9-0-3.wav processed with duration of 4.0 seconds.
# File 138015-3-0-5.wav processed with duration of 4.0 seconds.
# File 55020-4-0-13.wav processed with duration of 4.0 seconds.
# File 157867-8-0-12.wav processed with duration of 4.0 seconds.
# File 180937-7-0-6.wav processed with duration of 4.0 seconds.
# File 180937-7-1-11.wav processed with duration of 4.0 seconds.
# File 69304-9-0-12.wav processed with duration of 4.0 seconds.
# File 55020-4-0-8.wav processed with duration of 4.0 seconds.
# File 192124-2-0-3.wav processed with duration of 4.0 seconds.
# File 103074-7-4-4.wav processed with duration of 4.0 seconds.
# File 180937-7-2-4.wav processed with duration of 4.0 seconds.
# File 57320-0-0-32.wav processed with duration of 4.0 seconds.
# File 134717-0-0-24.wav processed with duration of 4.0 seconds.
# File 134717-0-0-18.wav processed with duration of 4.0 seconds.
# File 72579-3-0-4.wav processed with duration of 4.0 seconds.
# File 130030-3-0-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-147.wav processed with duration of 4.0 seconds.
# File 72579-3-0-0.wav processed with duration of 4.0 seconds.
# File 134717-0-0-20.wav processed with duration of 4.0 seconds.
# File 180937-7-2-0.wav processed with duration of 4.0 seconds.
# File 57320-0-0-36.wav processed with duration of 4.0 seconds.
# File 57320-0-0-22.wav processed with duration of 4.0 seconds.
# File 193394-3-0-4.wav processed with duration of 4.0 seconds.
# File 203356-3-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-4-0.wav processed with duration of 4.0 seconds.
# File 192124-2-0-7.wav processed with duration of 4.0 seconds.
# File 180937-7-1-15.wav processed with duration of 4.0 seconds.
# File 180937-7-0-2.wav processed with duration of 4.0 seconds.
# File 99180-9-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-16.wav processed with duration of 4.0 seconds.
# File 138015-3-0-1.wav processed with duration of 4.0 seconds.
# File 113205-5-1-2.wav processed with duration of 4.0 seconds.
# File 17592-5-1-1.wav processed with duration of 4.0 seconds.
# File 180937-7-3-10.wav processed with duration of 4.0 seconds.
# File 46669-4-0-10.wav processed with duration of 4.0 seconds.
# File 137156-9-0-5.wav processed with duration of 4.0 seconds.
# File 161702-9-0-6.wav processed with duration of 4.0 seconds.
# File 31840-3-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-4-6.wav processed with duration of 4.0 seconds.
# File 174276-7-3-0.wav processed with duration of 4.0 seconds.
# File 51022-3-30-4.wav processed with duration of 4.0 seconds.
# File 159738-8-0-7.wav processed with duration of 4.0 seconds.
# File 132016-9-0-16.wav processed with duration of 4.0 seconds.
# File 21684-9-0-50.wav processed with duration of 4.0 seconds.
# File 159738-8-0-6.wav processed with duration of 4.0 seconds.
# File 180937-7-4-7.wav processed with duration of 4.0 seconds.
# File 46669-4-0-39.wav processed with duration of 4.0 seconds.
# File 17592-5-1-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-11.wav processed with duration of 4.0 seconds.
# File 113205-5-1-3.wav processed with duration of 4.0 seconds.
# File 98223-7-7-0.wav processed with duration of 4.0 seconds.
# File 197318-6-7-0.wav processed with duration of 4.0 seconds.
# File 180937-7-1-14.wav processed with duration of 4.0 seconds.
# File 157867-8-0-17.wav processed with duration of 4.0 seconds.
# File 103074-7-4-1.wav processed with duration of 4.0 seconds.
# File 203356-3-0-1.wav processed with duration of 4.0 seconds.
# File 174294-6-0-0.wav processed with duration of 4.0 seconds.
# File 99180-9-0-36.wav processed with duration of 4.0 seconds.
# File 134717-0-0-21.wav processed with duration of 4.0 seconds.
# File 57320-0-0-37.wav processed with duration of 4.0 seconds.
# File 180937-7-2-1.wav processed with duration of 4.0 seconds.
# File 162540-1-2-0.wav processed with duration of 4.0 seconds.
# File 57553-3-0-0.wav processed with duration of 4.0 seconds.
# File 138031-2-0-23.wav processed with duration of 4.0 seconds.
# File 174294-6-2-0.wav processed with duration of 4.0 seconds.
# File 72579-3-0-3.wav processed with duration of 4.0 seconds.
# File 57320-0-0-21.wav processed with duration of 4.0 seconds.
# File 180937-7-2-3.wav processed with duration of 4.0 seconds.
# File 72261-3-0-27.wav processed with duration of 4.0 seconds.
# File 134717-0-0-23.wav processed with duration of 4.0 seconds.
# File 197318-6-5-0.wav processed with duration of 4.0 seconds.
# File 146186-5-0-8.wav processed with duration of 4.0 seconds.
# File 162540-1-0-0.wav processed with duration of 4.0 seconds.
# File 160094-3-0-0.wav processed with duration of 4.0 seconds.
# File 57553-3-2-0.wav processed with duration of 4.0 seconds.
# File 193394-3-0-7.wav processed with duration of 4.0 seconds.
# File 192124-2-0-4.wav processed with duration of 4.0 seconds.
# File 9031-3-2-0.wav processed with duration of 4.0 seconds.
# File 203356-3-0-3.wav processed with duration of 4.0 seconds.
# File 103074-7-4-3.wav processed with duration of 4.0 seconds.
# File 55020-4-0-14.wav processed with duration of 4.0 seconds.
# File 43806-8-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-15.wav processed with duration of 4.0 seconds.
# File 180937-7-0-1.wav processed with duration of 4.0 seconds.
# File 69304-9-0-15.wav processed with duration of 4.0 seconds.
# File 172314-9-0-22.wav processed with duration of 4.0 seconds.
# File 101415-3-0-3.wav processed with duration of 4.0 seconds.
# File 113205-5-1-1.wav processed with duration of 4.0 seconds.
# File 180937-7-3-13.wav processed with duration of 4.0 seconds.
# File 17592-5-1-2.wav processed with duration of 4.0 seconds.
# File 179867-1-0-0.wav processed with duration of 4.0 seconds.
# File 94868-1-1-0.wav processed with duration of 4.0 seconds.
# File 98223-7-5-0.wav processed with duration of 4.0 seconds.
# File 180937-7-4-5.wav processed with duration of 4.0 seconds.
# File 159738-8-0-4.wav processed with duration of 4.0 seconds.
# File 159738-8-0-5.wav processed with duration of 4.0 seconds.
# File 43786-3-0-0.wav processed with duration of 4.0 seconds.
# File 132016-9-0-14.wav processed with duration of 4.0 seconds.
# File 180937-7-4-4.wav processed with duration of 4.0 seconds.
# File 197073-3-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-12.wav processed with duration of 4.0 seconds.
# File 17592-5-1-3.wav processed with duration of 4.0 seconds.
# File 174276-7-1-0.wav processed with duration of 4.0 seconds.
# File 143651-2-0-39.wav processed with duration of 4.0 seconds.
# File 113205-5-1-0.wav processed with duration of 4.0 seconds.
# File 101415-3-0-2.wav processed with duration of 4.0 seconds.
# File 157867-8-0-28.wav processed with duration of 4.0 seconds.
# File 69304-9-0-14.wav processed with duration of 4.0 seconds.
# File 157867-8-0-14.wav processed with duration of 4.0 seconds.
# File 99180-9-0-2.wav processed with duration of 4.0 seconds.
# File 180937-7-0-0.wav processed with duration of 4.0 seconds.
# File 86278-6-0-0.wav processed with duration of 4.0 seconds.
# File 197318-6-11-0.wav processed with duration of 4.0 seconds.
# File 192124-2-0-5.wav processed with duration of 4.0 seconds.
# File 103074-7-4-2.wav processed with duration of 4.0 seconds.
# File 203356-3-0-2.wav processed with duration of 4.0 seconds.
# File 165642-4-0-0.wav processed with duration of 4.0 seconds.
# File 146186-5-0-9.wav processed with duration of 4.0 seconds.
# File 57320-0-0-34.wav processed with duration of 4.0 seconds.
# File 180937-7-2-2.wav processed with duration of 4.0 seconds.
# File 134717-0-0-22.wav processed with duration of 4.0 seconds.
# File 165645-4-5-0.wav processed with duration of 4.0 seconds.
# File 135776-2-0-65.wav processed with duration of 4.0 seconds.
# File 72579-3-0-2.wav processed with duration of 4.0 seconds.
# File 177621-0-0-145.wav processed with duration of 4.0 seconds.
# File 138031-2-0-22.wav processed with duration of 4.0 seconds.
# File 143604-5-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-1-1.wav processed with duration of 4.0 seconds.
# File 138031-2-0-45.wav processed with duration of 4.0 seconds.
# File 197318-6-2-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-10.wav processed with duration of 4.0 seconds.
# File 179858-1-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-3-3.wav processed with duration of 4.0 seconds.
# File 57320-0-0-9.wav processed with duration of 4.0 seconds.
# File 194732-9-0-95.wav processed with duration of 4.0 seconds.
# File 40722-8-0-1.wav processed with duration of 4.0 seconds.
# File 146186-5-0-13.wav processed with duration of 4.0 seconds.
# File 193698-2-0-42.wav processed with duration of 4.0 seconds.
# File 160009-2-0-11.wav processed with duration of 4.0 seconds.
# File 77766-9-0-4.wav processed with duration of 4.0 seconds.
# File 176787-5-0-26.wav processed with duration of 4.0 seconds.
# File 164053-8-2-1.wav processed with duration of 4.0 seconds.
# File 108362-2-0-30.wav processed with duration of 4.0 seconds.
# File 159738-8-0-19.wav processed with duration of 4.0 seconds.
# File 139951-9-0-45.wav processed with duration of 4.0 seconds.
# File 102305-6-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-1-7.wav processed with duration of 4.0 seconds.
# File 192124-2-0-15.wav processed with duration of 4.0 seconds.
# File 98223-7-2-0.wav processed with duration of 4.0 seconds.
# File 124489-9-0-17.wav processed with duration of 4.0 seconds.
# File 46669-4-0-49.wav processed with duration of 4.0 seconds.
# File 194732-9-0-126.wav processed with duration of 4.0 seconds.
# File 46669-4-0-61.wav processed with duration of 4.0 seconds.
# File 119455-5-0-7.wav processed with duration of 4.0 seconds.
# File 151977-0-0-2.wav processed with duration of 4.0 seconds.
# File 157867-8-0-1.wav processed with duration of 4.0 seconds.
# File 26270-9-0-30.wav processed with duration of 4.0 seconds.
# File 78360-4-0-14.wav processed with duration of 4.0 seconds.
# File 180937-7-3-5.wav processed with duration of 4.0 seconds.
# File 54858-3-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-4.wav processed with duration of 4.0 seconds.
# File 21684-9-0-5.wav processed with duration of 4.0 seconds.
# File 78360-4-0-15.wav processed with duration of 4.0 seconds.
# File 151977-0-0-3.wav processed with duration of 4.0 seconds.
# File 157867-8-0-0.wav processed with duration of 4.0 seconds.
# File 119455-5-0-6.wav processed with duration of 4.0 seconds.
# File 46669-4-0-48.wav processed with duration of 4.0 seconds.
# File 124489-9-0-16.wav processed with duration of 4.0 seconds.
# File 26270-9-0-19.wav processed with duration of 4.0 seconds.
# File 65749-3-1-14.wav processed with duration of 4.0 seconds.
# File 73277-9-0-28.wav processed with duration of 4.0 seconds.
# File 180937-7-1-6.wav processed with duration of 4.0 seconds.
# File 174276-7-6-0.wav processed with duration of 4.0 seconds.
# File 197073-3-7-0.wav processed with duration of 4.0 seconds.
# File 143651-2-0-63.wav processed with duration of 4.0 seconds.
# File 159738-8-0-18.wav processed with duration of 4.0 seconds.
# File 176257-3-0-0.wav processed with duration of 4.0 seconds.
# File 164053-8-2-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-88.wav processed with duration of 4.0 seconds.
# File 176787-5-0-27.wav processed with duration of 4.0 seconds.
# File 172314-9-0-51.wav processed with duration of 4.0 seconds.
# File 77766-9-0-5.wav processed with duration of 4.0 seconds.
# File 146186-5-0-12.wav processed with duration of 4.0 seconds.
# File 40722-8-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-3-2.wav processed with duration of 4.0 seconds.
# File 182800-2-1-0.wav processed with duration of 4.0 seconds.
# File 118101-3-0-0.wav processed with duration of 4.0 seconds.
# File 165645-4-2-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-11.wav processed with duration of 4.0 seconds.
# File 134717-0-0-2.wav processed with duration of 4.0 seconds.
# File 103074-7-1-0.wav processed with duration of 4.0 seconds.
# File 103074-7-1-2.wav processed with duration of 4.0 seconds.
# File 182800-2-3-0.wav processed with duration of 4.0 seconds.
# File 127873-0-0-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-109.wav processed with duration of 4.0 seconds.
# File 176258-3-1-12.wav processed with duration of 4.0 seconds.
# File 103258-5-0-13.wav processed with duration of 4.0 seconds.
# File 134717-0-0-0.wav processed with duration of 4.0 seconds.
# File 164053-8-0-0.wav processed with duration of 4.0 seconds.
# File 103074-7-3-0.wav processed with duration of 4.0 seconds.
# File 146186-5-0-10.wav processed with duration of 4.0 seconds.
# File 203440-3-0-1.wav processed with duration of 4.0 seconds.
# File 40722-8-0-2.wav processed with duration of 4.0 seconds.
# File 176787-5-0-25.wav processed with duration of 4.0 seconds.
# File 77766-9-0-7.wav processed with duration of 4.0 seconds.
# File 194732-9-0-41.wav processed with duration of 4.0 seconds.
# File 176787-5-0-19.wav processed with duration of 4.0 seconds.
# File 165645-4-0-0.wav processed with duration of 4.0 seconds.
# File 164053-8-2-2.wav processed with duration of 4.0 seconds.
# File 78360-4-0-8.wav processed with duration of 4.0 seconds.
# File 44736-5-0-1.wav processed with duration of 4.0 seconds.
# File 73277-9-0-16.wav processed with duration of 4.0 seconds.
# File 193698-2-0-113.wav processed with duration of 4.0 seconds.
# File 180937-7-1-4.wav processed with duration of 4.0 seconds.
# File 124489-9-0-14.wav processed with duration of 4.0 seconds.
# File 165067-2-0-72.wav processed with duration of 4.0 seconds.
# File 7061-6-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-2.wav processed with duration of 4.0 seconds.
# File 151977-0-0-1.wav processed with duration of 4.0 seconds.
# File 119455-5-0-4.wav processed with duration of 4.0 seconds.
# File 78360-4-0-17.wav processed with duration of 4.0 seconds.
# File 46669-4-0-8.wav processed with duration of 4.0 seconds.
# File 21684-9-0-7.wav processed with duration of 4.0 seconds.
# File 174276-7-4-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-6.wav processed with duration of 4.0 seconds.
# File 180937-7-3-7.wav processed with duration of 4.0 seconds.
# File 46669-4-0-9.wav processed with duration of 4.0 seconds.
# File 78360-4-0-16.wav processed with duration of 4.0 seconds.
# File 119455-5-0-5.wav processed with duration of 4.0 seconds.
# File 46669-4-0-63.wav processed with duration of 4.0 seconds.
# File 19026-1-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-3.wav processed with duration of 4.0 seconds.
# File 26270-9-0-32.wav processed with duration of 4.0 seconds.
# File 151977-0-0-0.wav processed with duration of 4.0 seconds.
# File 191431-9-0-61.wav processed with duration of 4.0 seconds.
# File 180937-7-1-5.wav processed with duration of 4.0 seconds.
# File 54858-3-2-0.wav processed with duration of 4.0 seconds.
# File 193698-2-0-112.wav processed with duration of 4.0 seconds.
# File 73277-9-0-17.wav processed with duration of 4.0 seconds.
# File 44736-5-0-0.wav processed with duration of 4.0 seconds.
# File 98223-7-0-0.wav processed with duration of 4.0 seconds.
# File 17913-4-1-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-9.wav processed with duration of 4.0 seconds.
# File 164053-8-2-3.wav processed with duration of 4.0 seconds.
# File 196079-2-0-0.wav processed with duration of 4.0 seconds.
# File 176787-5-0-18.wav processed with duration of 4.0 seconds.
# File 197318-6-0-0.wav processed with duration of 4.0 seconds.
# File 77766-9-0-6.wav processed with duration of 4.0 seconds.
# File 176787-5-0-30.wav processed with duration of 4.0 seconds.
# File 172314-9-0-52.wav processed with duration of 4.0 seconds.
# File 176787-5-0-24.wav processed with duration of 4.0 seconds.
# File 40722-8-0-3.wav processed with duration of 4.0 seconds.
# File 177621-0-0-48.wav processed with duration of 4.0 seconds.
# File 203440-3-0-0.wav processed with duration of 4.0 seconds.
# File 146186-5-0-11.wav processed with duration of 4.0 seconds.
# File 118101-3-0-3.wav processed with duration of 4.0 seconds.
# File 103074-7-3-1.wav processed with duration of 4.0 seconds.
# File 57320-0-0-45.wav processed with duration of 4.0 seconds.
# File 134717-0-0-1.wav processed with duration of 4.0 seconds.
# File 176258-3-1-13.wav processed with duration of 4.0 seconds.
# File 103258-5-0-12.wav processed with duration of 4.0 seconds.
# File 138031-2-0-47.wav processed with duration of 4.0 seconds.
# File 177621-0-0-120.wav processed with duration of 4.0 seconds.
# File 182800-2-3-1.wav processed with duration of 4.0 seconds.
# File 103074-7-1-3.wav processed with duration of 4.0 seconds.
# File 24074-1-0-8.wav processed with duration of 4.0 seconds.
# File 98223-7-4-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-16.wav processed with duration of 4.0 seconds.
# File 134717-0-0-5.wav processed with duration of 4.0 seconds.
# File 40722-8-0-7.wav processed with duration of 4.0 seconds.
# File 184355-1-0-0.wav processed with duration of 4.0 seconds.
# File 106905-8-0-1.wav processed with duration of 4.0 seconds.
# File 176787-5-0-20.wav processed with duration of 4.0 seconds.
# File 94868-1-0-0.wav processed with duration of 4.0 seconds.
# File 162540-1-1-0.wav processed with duration of 4.0 seconds.
# File 9031-3-3-0.wav processed with duration of 4.0 seconds.
# File 180937-7-1-1.wav processed with duration of 4.0 seconds.
# File 155202-9-0-42.wav processed with duration of 4.0 seconds.
# File 51022-3-13-0.wav processed with duration of 4.0 seconds.
# File 73277-9-0-0.wav processed with duration of 4.0 seconds.
# File 151977-0-0-4.wav processed with duration of 4.0 seconds.
# File 157867-8-0-7.wav processed with duration of 4.0 seconds.
# File 14113-4-0-1.wav processed with duration of 4.0 seconds.
# File 119455-5-0-1.wav processed with duration of 4.0 seconds.
# File 103258-5-0-9.wav processed with duration of 4.0 seconds.
# File 180937-7-3-3.wav processed with duration of 4.0 seconds.
# File 197318-6-4-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-12.wav processed with duration of 4.0 seconds.
# File 103258-5-0-8.wav processed with duration of 4.0 seconds.
# File 30823-8-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-2.wav processed with duration of 4.0 seconds.
# File 165645-4-4-0.wav processed with duration of 4.0 seconds.
# File 165067-2-0-111.wav processed with duration of 4.0 seconds.
# File 65749-3-1-12.wav processed with duration of 4.0 seconds.
# File 192124-2-0-12.wav processed with duration of 4.0 seconds.
# File 26270-9-0-23.wav processed with duration of 4.0 seconds.
# File 14113-4-0-0.wav processed with duration of 4.0 seconds.
# File 119455-5-0-0.wav processed with duration of 4.0 seconds.
# File 151977-0-0-5.wav processed with duration of 4.0 seconds.
# File 157867-8-0-6.wav processed with duration of 4.0 seconds.
# File 180937-7-1-0.wav processed with duration of 4.0 seconds.
# File 143651-2-0-59.wav processed with duration of 4.0 seconds.
# File 108362-2-0-23.wav processed with duration of 4.0 seconds.
# File 197318-6-10-0.wav processed with duration of 4.0 seconds.
# File 108362-2-0-7.wav processed with duration of 4.0 seconds.
# File 77766-9-0-3.wav processed with duration of 4.0 seconds.
# File 176787-5-0-21.wav processed with duration of 4.0 seconds.
# File 106905-8-0-0.wav processed with duration of 4.0 seconds.
# File 15564-2-0-2.wav processed with duration of 4.0 seconds.
# File 174276-7-0-0.wav processed with duration of 4.0 seconds.
# File 172314-9-0-80.wav processed with duration of 4.0 seconds.
# File 113205-5-0-0.wav processed with duration of 4.0 seconds.
# File 118101-3-0-6.wav processed with duration of 4.0 seconds.
# File 40722-8-0-6.wav processed with duration of 4.0 seconds.
# File 203440-3-0-5.wav processed with duration of 4.0 seconds.
# File 134717-0-0-4.wav processed with duration of 4.0 seconds.
# File 43786-3-1-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-17.wav processed with duration of 4.0 seconds.
# File 24074-1-0-9.wav processed with duration of 4.0 seconds.
# File 103074-7-1-6.wav processed with duration of 4.0 seconds.
# File 177621-0-0-127.wav processed with duration of 4.0 seconds.
# File 65749-3-1-9.wav processed with duration of 4.0 seconds.
# File 103074-7-1-4.wav processed with duration of 4.0 seconds.
# File 31840-3-1-0.wav processed with duration of 4.0 seconds.
# File 57320-0-0-42.wav processed with duration of 4.0 seconds.
# File 174276-7-2-0.wav processed with duration of 4.0 seconds.
# File 176714-2-0-77.wav processed with duration of 4.0 seconds.
# File 134717-0-0-6.wav processed with duration of 4.0 seconds.
# File 197073-3-3-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-15.wav processed with duration of 4.0 seconds.
# File 40722-8-0-4.wav processed with duration of 4.0 seconds.
# File 118101-3-0-4.wav processed with duration of 4.0 seconds.
# File 15564-2-0-0.wav processed with duration of 4.0 seconds.
# File 106905-8-0-2.wav processed with duration of 4.0 seconds.
# File 176787-5-0-23.wav processed with duration of 4.0 seconds.
# File 108362-2-0-21.wav processed with duration of 4.0 seconds.
# File 180937-7-1-2.wav processed with duration of 4.0 seconds.
# File 108041-9-0-11.wav processed with duration of 4.0 seconds.
# File 119455-5-0-2.wav processed with duration of 4.0 seconds.
# File 157867-8-0-4.wav processed with duration of 4.0 seconds.
# File 26270-9-0-35.wav processed with duration of 4.0 seconds.
# File 151977-0-0-7.wav processed with duration of 4.0 seconds.
# File 191431-9-0-66.wav processed with duration of 4.0 seconds.
# File 197318-6-12-0.wav processed with duration of 4.0 seconds.
# File 124489-9-0-12.wav processed with duration of 4.0 seconds.
# File 105415-2-0-15.wav processed with duration of 4.0 seconds.
# File 180937-7-3-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-11.wav processed with duration of 4.0 seconds.
# File 21684-9-0-25.wav processed with duration of 4.0 seconds.
# File 21684-9-0-30.wav processed with duration of 4.0 seconds.
# File 165067-2-0-112.wav processed with duration of 4.0 seconds.
# File 180937-7-3-1.wav processed with duration of 4.0 seconds.
# File 51022-3-7-0.wav processed with duration of 4.0 seconds.
# File 191431-9-0-73.wav processed with duration of 4.0 seconds.
# File 192124-2-0-11.wav processed with duration of 4.0 seconds.
# File 9031-3-1-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-5.wav processed with duration of 4.0 seconds.
# File 151977-0-0-6.wav processed with duration of 4.0 seconds.
# File 57553-3-1-0.wav processed with duration of 4.0 seconds.
# File 119455-5-0-3.wav processed with duration of 4.0 seconds.
# File 197318-6-6-0.wav processed with duration of 4.0 seconds.
# File 193698-2-0-114.wav processed with duration of 4.0 seconds.
# File 137156-9-0-28.wav processed with duration of 4.0 seconds.
# File 180937-7-1-3.wav processed with duration of 4.0 seconds.
# File 174294-6-1-0.wav processed with duration of 4.0 seconds.
# File 172314-9-0-40.wav processed with duration of 4.0 seconds.
# File 176787-5-0-22.wav processed with duration of 4.0 seconds.
# File 77766-9-0-0.wav processed with duration of 4.0 seconds.
# File 15564-2-0-1.wav processed with duration of 4.0 seconds.
# File 106905-8-0-3.wav processed with duration of 4.0 seconds.
# File 17592-5-0-0.wav processed with duration of 4.0 seconds.
# File 98223-7-6-0.wav processed with duration of 4.0 seconds.
# File 40722-8-0-5.wav processed with duration of 4.0 seconds.
# File 203440-3-0-6.wav processed with duration of 4.0 seconds.
# File 103258-5-0-14.wav processed with duration of 4.0 seconds.
# File 134717-0-0-7.wav processed with duration of 4.0 seconds.
# File 94868-1-2-0.wav processed with duration of 4.0 seconds.
# File 103074-7-1-5.wav processed with duration of 4.0 seconds.
# File 177621-0-0-126.wav processed with duration of 4.0 seconds.
# File 135776-2-0-37.wav processed with duration of 4.0 seconds.
# File 177621-0-0-117.wav processed with duration of 4.0 seconds.
# File 24074-1-0-7.wav processed with duration of 4.0 seconds.
# File 166268-3-1-0.wav processed with duration of 4.0 seconds.
# File 86279-3-0-0.wav processed with duration of 4.0 seconds.
# File 176258-3-1-18.wav processed with duration of 4.0 seconds.
# File 103258-5-0-19.wav processed with duration of 4.0 seconds.
# File 31323-3-0-22.wav processed with duration of 4.0 seconds.
# File 177621-0-0-57.wav processed with duration of 4.0 seconds.
# File 40722-8-0-8.wav processed with duration of 4.0 seconds.
# File 57320-0-0-0.wav processed with duration of 4.0 seconds.
# File 96158-4-0-0.wav processed with duration of 4.0 seconds.
# File 160009-2-0-30.wav processed with duration of 4.0 seconds.
# File 176787-5-0-13.wav processed with duration of 4.0 seconds.
# File 177621-0-0-80.wav processed with duration of 4.0 seconds.
# File 108362-2-0-9.wav processed with duration of 4.0 seconds.
# File 108362-2-0-11.wav processed with duration of 4.0 seconds.
# File 159738-8-0-10.wav processed with duration of 4.0 seconds.
# File 24074-1-0-10.wav processed with duration of 4.0 seconds.
# File 78360-4-0-2.wav processed with duration of 4.0 seconds.
# File 114587-3-0-2.wav processed with duration of 4.0 seconds.
# File 137156-9-0-31.wav processed with duration of 4.0 seconds.
# File 157867-8-0-8.wav processed with duration of 4.0 seconds.
# File 105415-2-0-19.wav processed with duration of 4.0 seconds.
# File 46669-4-0-54.wav processed with duration of 4.0 seconds.
# File 78360-4-0-21.wav processed with duration of 4.0 seconds.
# File 87275-1-2-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-6.wav processed with duration of 4.0 seconds.
# File 46669-4-0-2.wav processed with duration of 4.0 seconds.
# File 46669-4-0-3.wav processed with duration of 4.0 seconds.
# File 147764-4-1-0.wav processed with duration of 4.0 seconds.
# File 164312-3-0-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-20.wav processed with duration of 4.0 seconds.
# File 103258-5-0-7.wav processed with duration of 4.0 seconds.
# File 88466-7-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-9.wav processed with duration of 4.0 seconds.
# File 46656-6-0-0.wav processed with duration of 4.0 seconds.
# File 105415-2-0-24.wav processed with duration of 4.0 seconds.
# File 137156-9-0-30.wav processed with duration of 4.0 seconds.
# File 24074-1-0-11.wav processed with duration of 4.0 seconds.
# File 159738-8-0-11.wav processed with duration of 4.0 seconds.
# File 78360-4-0-3.wav processed with duration of 4.0 seconds.
# File 193698-2-0-89.wav processed with duration of 4.0 seconds.
# File 160009-2-0-31.wav processed with duration of 4.0 seconds.
# File 176787-5-0-12.wav processed with duration of 4.0 seconds.
# File 150341-3-0-0.wav processed with duration of 4.0 seconds.
# File 174290-6-0-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-18.wav processed with duration of 4.0 seconds.
# File 24074-1-0-6.wav processed with duration of 4.0 seconds.
# File 177621-0-0-128.wav processed with duration of 4.0 seconds.
# File 177621-0-0-100.wav processed with duration of 4.0 seconds.
# File 24074-1-0-4.wav processed with duration of 4.0 seconds.
# File 134717-0-0-9.wav processed with duration of 4.0 seconds.
# File 177621-0-0-54.wav processed with duration of 4.0 seconds.
# File 176787-5-0-10.wav processed with duration of 4.0 seconds.
# File 172314-9-0-72.wav processed with duration of 4.0 seconds.
# File 174290-6-2-0.wav processed with duration of 4.0 seconds.
# File 71087-4-1-0.wav processed with duration of 4.0 seconds.
# File 108362-2-0-12.wav processed with duration of 4.0 seconds.
# File 46656-6-2-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-1.wav processed with duration of 4.0 seconds.
# File 159738-8-0-13.wav processed with duration of 4.0 seconds.
# File 24074-1-0-13.wav processed with duration of 4.0 seconds.
# File 147764-4-3-0.wav processed with duration of 4.0 seconds.
# File 151977-0-0-8.wav processed with duration of 4.0 seconds.
# File 103258-5-0-5.wav processed with duration of 4.0 seconds.
# File 78360-4-0-22.wav processed with duration of 4.0 seconds.
# File 46669-4-0-0.wav processed with duration of 4.0 seconds.
# File 102842-3-0-1.wav processed with duration of 4.0 seconds.
# File 161702-9-0-37.wav processed with duration of 4.0 seconds.
# File 103258-5-0-4.wav processed with duration of 4.0 seconds.
# File 165067-2-0-91.wav processed with duration of 4.0 seconds.
# File 78360-4-0-23.wav processed with duration of 4.0 seconds.
# File 160009-2-0-1.wav processed with duration of 4.0 seconds.
# File 151977-0-0-9.wav processed with duration of 4.0 seconds.
# File 87275-1-0-0.wav processed with duration of 4.0 seconds.
# File 143651-2-0-55.wav processed with duration of 4.0 seconds.
# File 78360-4-0-0.wav processed with duration of 4.0 seconds.
# File 24074-1-0-12.wav processed with duration of 4.0 seconds.
# File 159738-8-0-12.wav processed with duration of 4.0 seconds.
# File 197318-6-8-0.wav processed with duration of 4.0 seconds.
# File 98223-7-8-0.wav processed with duration of 4.0 seconds.
# File 176787-5-0-11.wav processed with duration of 4.0 seconds.
# File 176258-3-1-2.wav processed with duration of 4.0 seconds.
# File 31323-3-0-20.wav processed with duration of 4.0 seconds.
# File 176714-2-0-51.wav processed with duration of 4.0 seconds.
# File 134717-0-0-8.wav processed with duration of 4.0 seconds.
# File 24074-1-0-5.wav processed with duration of 4.0 seconds.
# File 177621-0-0-105.wav processed with duration of 4.0 seconds.
# File 83199-9-0-0.wav processed with duration of 4.0 seconds.
# File 24074-1-0-1.wav processed with duration of 4.0 seconds.
# File 180256-3-0-2.wav processed with duration of 4.0 seconds.
# File 176714-2-0-55.wav processed with duration of 4.0 seconds.
# File 175851-1-0-0.wav processed with duration of 4.0 seconds.
# File 7383-3-0-0.wav processed with duration of 4.0 seconds.
# File 87275-1-4-0.wav processed with duration of 4.0 seconds.
# File 99180-9-0-49.wav processed with duration of 4.0 seconds.
# File 57320-0-0-6.wav processed with duration of 4.0 seconds.
# File 176787-5-0-29.wav processed with duration of 4.0 seconds.
# File 160009-2-0-22.wav processed with duration of 4.0 seconds.
# File 176787-5-0-15.wav processed with duration of 4.0 seconds.
# File 72261-3-0-6.wav processed with duration of 4.0 seconds.
# File 159738-8-0-16.wav processed with duration of 4.0 seconds.
# File 78360-4-0-4.wav processed with duration of 4.0 seconds.
# File 193394-3-0-11.wav processed with duration of 4.0 seconds.
# File 114587-3-0-4.wav processed with duration of 4.0 seconds.
# File 180937-7-1-8.wav processed with duration of 4.0 seconds.
# File 76093-6-0-0.wav processed with duration of 4.0 seconds.
# File 139951-9-0-9.wav processed with duration of 4.0 seconds.
# File 160009-2-0-5.wav processed with duration of 4.0 seconds.
# File 124489-9-0-18.wav processed with duration of 4.0 seconds.
# File 165067-2-0-56.wav processed with duration of 4.0 seconds.
# File 175845-1-0-0.wav processed with duration of 4.0 seconds.
# File 98223-7-10-0.wav processed with duration of 4.0 seconds.
# File 46669-4-0-4.wav processed with duration of 4.0 seconds.
# File 103258-5-0-0.wav processed with duration of 4.0 seconds.
# File 161702-9-0-26.wav processed with duration of 4.0 seconds.
# File 162703-1-0-0.wav processed with duration of 4.0 seconds.
# File 103258-5-0-1.wav processed with duration of 4.0 seconds.
# File 21684-9-0-12.wav processed with duration of 4.0 seconds.
# File 114587-3-0-5.wav processed with duration of 4.0 seconds.
# File 180937-7-1-9.wav processed with duration of 4.0 seconds.
# File 193394-3-0-10.wav processed with duration of 4.0 seconds.
# File 159738-8-0-17.wav processed with duration of 4.0 seconds.
# File 78360-4-0-5.wav processed with duration of 4.0 seconds.
# File 176787-5-0-14.wav processed with duration of 4.0 seconds.
# File 177621-0-0-93.wav processed with duration of 4.0 seconds.
# File 176787-5-0-28.wav processed with duration of 4.0 seconds.
# File 196065-2-0-0.wav processed with duration of 4.0 seconds.
# File 124489-9-0-6.wav processed with duration of 4.0 seconds.
# File 193698-2-0-58.wav processed with duration of 4.0 seconds.
# File 57320-0-0-7.wav processed with duration of 4.0 seconds.
# File 193698-2-0-64.wav processed with duration of 4.0 seconds.
# File 99180-9-0-48.wav processed with duration of 4.0 seconds.
# File 7383-3-0-1.wav processed with duration of 4.0 seconds.
# File 176714-2-0-40.wav processed with duration of 4.0 seconds.
# File 147764-4-7-0.wav processed with duration of 4.0 seconds.
# File 180256-3-0-3.wav processed with duration of 4.0 seconds.
# File 24074-1-0-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-104.wav processed with duration of 4.0 seconds.
# File 24074-1-0-2.wav processed with duration of 4.0 seconds.
# File 135776-2-0-32.wav processed with duration of 4.0 seconds.
# File 180256-3-0-1.wav processed with duration of 4.0 seconds.
# File 57320-0-0-5.wav processed with duration of 4.0 seconds.
# File 176638-1-1-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-46.wav processed with duration of 4.0 seconds.
# File 46656-6-4-0.wav processed with duration of 4.0 seconds.
# File 147764-4-5-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-91.wav processed with duration of 4.0 seconds.
# File 164312-3-4-0.wav processed with duration of 4.0 seconds.
# File 176787-5-0-16.wav processed with duration of 4.0 seconds.
# File 78360-4-0-7.wav processed with duration of 4.0 seconds.
# File 159738-8-0-15.wav processed with duration of 4.0 seconds.
# File 50901-0-1-0.wav processed with duration of 4.0 seconds.
# File 73277-9-0-19.wav processed with duration of 4.0 seconds.
# File 118963-3-0-0.wav processed with duration of 4.0 seconds.
# File 114587-3-0-7.wav processed with duration of 4.0 seconds.
# File 165067-2-0-9.wav processed with duration of 4.0 seconds.
# File 46669-4-0-45.wav processed with duration of 4.0 seconds.
# File 102106-3-0-0.wav processed with duration of 4.0 seconds.
# File 78360-4-0-18.wav processed with duration of 4.0 seconds.
# File 161702-9-0-30.wav processed with duration of 4.0 seconds.
# File 103258-5-0-3.wav processed with duration of 4.0 seconds.
# File 180937-7-3-9.wav processed with duration of 4.0 seconds.
# File 103258-5-0-2.wav processed with duration of 4.0 seconds.
# File 180937-7-3-8.wav processed with duration of 4.0 seconds.
# File 78360-4-0-19.wav processed with duration of 4.0 seconds.
# File 21684-9-0-39.wav processed with duration of 4.0 seconds.
# File 65749-3-1-24.wav processed with duration of 4.0 seconds.
# File 105415-2-0-21.wav processed with duration of 4.0 seconds.
# File 77246-6-0-0.wav processed with duration of 4.0 seconds.
# File 73277-9-0-24.wav processed with duration of 4.0 seconds.
# File 50901-0-1-1.wav processed with duration of 4.0 seconds.
# File 108362-2-0-29.wav processed with duration of 4.0 seconds.
# File 78360-4-0-6.wav processed with duration of 4.0 seconds.
# File 159738-8-0-14.wav processed with duration of 4.0 seconds.
# File 176787-5-0-17.wav processed with duration of 4.0 seconds.
# File 177621-0-0-47.wav processed with duration of 4.0 seconds.
# File 57320-0-0-4.wav processed with duration of 4.0 seconds.
# File 180937-7-2-10.wav processed with duration of 4.0 seconds.
# File 180256-3-0-0.wav processed with duration of 4.0 seconds.
# File 24074-1-0-3.wav processed with duration of 4.0 seconds.
# File 97317-2-0-36.wav processed with duration of 4.0 seconds.
# File 135776-2-0-40.wav processed with duration of 4.0 seconds.
# File 97317-2-0-22.wav processed with duration of 4.0 seconds.
# File 138031-2-0-13.wav processed with duration of 4.0 seconds.
# File 176714-2-0-18.wav processed with duration of 4.0 seconds.
# File 57320-0-0-39.wav processed with duration of 4.0 seconds.
# File 102842-3-1-0.wav processed with duration of 4.0 seconds.
# File 72261-3-0-17.wav processed with duration of 4.0 seconds.
# File 134717-0-0-13.wav processed with duration of 4.0 seconds.
# File 146186-5-0-4.wav processed with duration of 4.0 seconds.
# File 57320-0-0-11.wav processed with duration of 4.0 seconds.
# File 46656-6-3-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-19.wav processed with duration of 4.0 seconds.
# File 164312-3-3-0.wav processed with duration of 4.0 seconds.
# File 160009-2-0-47.wav processed with duration of 4.0 seconds.
# File 176787-5-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-25.wav processed with duration of 4.0 seconds.
# File 55020-4-0-3.wav processed with duration of 4.0 seconds.
# File 147764-4-2-0.wav processed with duration of 4.0 seconds.
# File 139951-9-0-13.wav processed with duration of 4.0 seconds.
# File 57584-4-0-1.wav processed with duration of 4.0 seconds.
# File 143651-2-0-20.wav processed with duration of 4.0 seconds.
# File 180937-7-3-23.wav processed with duration of 4.0 seconds.
# File 71087-4-0-0.wav processed with duration of 4.0 seconds.
# File 174290-6-3-0.wav processed with duration of 4.0 seconds.
# File 46918-5-0-1.wav processed with duration of 4.0 seconds.
# File 118279-8-0-1.wav processed with duration of 4.0 seconds.
# File 46669-4-0-37.wav processed with duration of 4.0 seconds.
# File 59277-0-0-3.wav processed with duration of 4.0 seconds.
# File 180937-7-4-9.wav processed with duration of 4.0 seconds.
# File 159738-8-0-8.wav processed with duration of 4.0 seconds.
# File 118279-8-0-14.wav processed with duration of 4.0 seconds.
# File 159738-8-0-9.wav processed with duration of 4.0 seconds.
# File 180937-7-4-8.wav processed with duration of 4.0 seconds.
# File 59277-0-0-2.wav processed with duration of 4.0 seconds.
# File 46669-4-0-36.wav processed with duration of 4.0 seconds.
# File 194732-9-0-171.wav processed with duration of 4.0 seconds.
# File 161702-9-0-8.wav processed with duration of 4.0 seconds.
# File 118279-8-0-0.wav processed with duration of 4.0 seconds.
# File 46918-5-0-0.wav processed with duration of 4.0 seconds.
# File 98223-7-9-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-22.wav processed with duration of 4.0 seconds.
# File 57584-4-0-0.wav processed with duration of 4.0 seconds.
# File 166268-3-2-0.wav processed with duration of 4.0 seconds.
# File 89948-5-0-0.wav processed with duration of 4.0 seconds.
# File 55020-4-0-2.wav processed with duration of 4.0 seconds.
# File 157867-8-0-24.wav processed with duration of 4.0 seconds.
# File 176787-5-0-1.wav processed with duration of 4.0 seconds.
# File 157867-8-0-18.wav processed with duration of 4.0 seconds.
# File 87275-1-1-0.wav processed with duration of 4.0 seconds.
# File 197318-6-9-0.wav processed with duration of 4.0 seconds.
# File 177621-0-0-35.wav processed with duration of 4.0 seconds.
# File 155202-9-0-135.wav processed with duration of 4.0 seconds.
# File 57320-0-0-10.wav processed with duration of 4.0 seconds.
# File 146186-5-0-5.wav processed with duration of 4.0 seconds.
# File 134717-0-0-12.wav processed with duration of 4.0 seconds.
# File 122690-6-0-0.wav processed with duration of 4.0 seconds.
# File 57320-0-0-38.wav processed with duration of 4.0 seconds.
# File 97317-2-0-23.wav processed with duration of 4.0 seconds.
# File 87275-1-3-0.wav processed with duration of 4.0 seconds.
# File 176714-2-0-33.wav processed with duration of 4.0 seconds.
# File 146186-5-0-7.wav processed with duration of 4.0 seconds.
# File 176787-5-0-3.wav processed with duration of 4.0 seconds.
# File 160009-2-0-50.wav processed with duration of 4.0 seconds.
# File 55020-4-0-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-26.wav processed with duration of 4.0 seconds.
# File 196400-6-0-0.wav processed with duration of 4.0 seconds.
# File 125791-3-0-13.wav processed with duration of 4.0 seconds.
# File 69304-9-0-7.wav processed with duration of 4.0 seconds.
# File 57584-4-0-2.wav processed with duration of 4.0 seconds.
# File 137156-9-0-79.wav processed with duration of 4.0 seconds.
# File 46918-5-0-2.wav processed with duration of 4.0 seconds.
# File 118279-8-0-2.wav processed with duration of 4.0 seconds.
# File 108041-9-0-2.wav processed with duration of 4.0 seconds.
# File 180937-7-3-20.wav processed with duration of 4.0 seconds.
# File 166268-3-0-0.wav processed with duration of 4.0 seconds.
# File 105415-2-0-1.wav processed with duration of 4.0 seconds.
# File 59277-0-0-0.wav processed with duration of 4.0 seconds.
# File 174290-6-1-0.wav processed with duration of 4.0 seconds.
# File 59277-0-0-1.wav processed with duration of 4.0 seconds.
# File 46669-4-0-35.wav processed with duration of 4.0 seconds.
# File 132016-9-0-0.wav processed with duration of 4.0 seconds.
# File 138031-2-0-7.wav processed with duration of 4.0 seconds.
# File 180937-7-3-21.wav processed with duration of 4.0 seconds.
# File 118279-8-0-3.wav processed with duration of 4.0 seconds.
# File 180937-7-4-14.wav processed with duration of 4.0 seconds.
# File 155202-9-0-38.wav processed with duration of 4.0 seconds.
# File 143651-2-0-22.wav processed with duration of 4.0 seconds.
# File 57584-4-0-3.wav processed with duration of 4.0 seconds.
# File 69304-9-0-6.wav processed with duration of 4.0 seconds.
# File 125791-3-0-12.wav processed with duration of 4.0 seconds.
# File 150341-3-1-0.wav processed with duration of 4.0 seconds.
# File 157867-8-0-27.wav processed with duration of 4.0 seconds.
# File 55020-4-0-1.wav processed with duration of 4.0 seconds.
# File 176787-5-0-2.wav processed with duration of 4.0 seconds.
# File 146186-5-0-6.wav processed with duration of 4.0 seconds.
# File 176714-2-0-26.wav processed with duration of 4.0 seconds.
# File 57320-0-0-13.wav processed with duration of 4.0 seconds.
# File 147764-4-0-0.wav processed with duration of 4.0 seconds.
# File 164312-3-1-0.wav processed with duration of 4.0 seconds.
# File 196087-2-0-0.wav processed with duration of 4.0 seconds.
# File 97317-2-0-34.wav processed with duration of 4.0 seconds.
# File 46656-6-1-0.wav processed with duration of 4.0 seconds.
# File 134717-0-0-15.wav processed with duration of 4.0 seconds.
# File 146186-5-0-2.wav processed with duration of 4.0 seconds.
# File 135776-2-0-85.wav processed with duration of 4.0 seconds.
# File 102842-3-1-6.wav processed with duration of 4.0 seconds.
# File 180937-7-2-9.wav processed with duration of 4.0 seconds.
# File 22962-4-0-0.wav processed with duration of 4.0 seconds.
# File 50901-0-0-0.wav processed with duration of 4.0 seconds.
# File 155202-9-0-126.wav processed with duration of 4.0 seconds.
# File 55020-4-0-5.wav processed with duration of 4.0 seconds.
# File 157867-8-0-23.wav processed with duration of 4.0 seconds.
# File 151977-0-0-10.wav processed with duration of 4.0 seconds.
# File 176787-5-0-6.wav processed with duration of 4.0 seconds.
# File 57584-4-0-7.wav processed with duration of 4.0 seconds.
# File 139951-9-0-29.wav processed with duration of 4.0 seconds.
# File 46656-6-5-0.wav processed with duration of 4.0 seconds.
# File 176638-1-0-0.wav processed with duration of 4.0 seconds.
# File 180937-7-3-31.wav processed with duration of 4.0 seconds.
# ...
# File 11722-3-1-0.wav processed with duration of 4.0 seconds.
# File 167464-0-0-3.wav processed with duration of 4.0 seconds.
# File 74364-8-1-11.wav processed with duration of 4.0 seconds.
# File 171478-9-0-57.wav processed with duration of 4.0 seconds.
# File 102857-5-0-17.wav processed with duration of 4.0 seconds.
# File 164194-2-0-24.wav processed with duration of 4.0 seconds.
# File 164194-2-0-18.wav processed with duration of 4.0 seconds.
# File 188813-7-1-0.wav processed with duration of 4.0 seconds.
# File 180127-4-0-9.wav processed with duration of 4.0 seconds.
# File 15544-5-0-0.wav processed with duration of 4.0 seconds.
# File 167464-0-0-20.wav processed with duration of 4.0 seconds.
# File 27070-2-0-5.wav processed with duration of 4.0 seconds.
# File 27070-2-0-4.wav processed with duration of 4.0 seconds.
# File 167464-0-0-21.wav processed with duration of 4.0 seconds.
# File 15544-5-0-1.wav processed with duration of 4.0 seconds.
# File 171478-9-0-4.wav processed with duration of 4.0 seconds.
# File 180127-4-0-8.wav processed with duration of 4.0 seconds.
# File 128240-3-0-20.wav processed with duration of 4.0 seconds.
# File 102857-5-0-16.wav processed with duration of 4.0 seconds.
# File 73524-0-0-54.wav processed with duration of 4.0 seconds.
# File 74364-8-1-10.wav processed with duration of 4.0 seconds.
# File 167464-0-0-2.wav processed with duration of 4.0 seconds.
# File 83502-0-0-7.wav processed with duration of 4.0 seconds.
# File 165640-4-0-2.wav processed with duration of 4.0 seconds.
# File 117889-9-0-36.wav processed with duration of 4.0 seconds.
# File 208652-8-4-0.wav processed with duration of 4.0 seconds.
# File 118278-4-0-8.wav processed with duration of 4.0 seconds.
# File 179868-1-0-0.wav processed with duration of 4.0 seconds.
# File 188497-2-0-0.wav processed with duration of 4.0 seconds.
# File 15544-5-0-19.wav processed with duration of 4.0 seconds.
# File 189982-0-0-36.wav processed with duration of 4.0 seconds.
# File 88121-8-1-0.wav processed with duration of 4.0 seconds.
# File 85574-3-0-0.wav processed with duration of 4.0 seconds.
# File 74922-4-0-3.wav processed with duration of 4.0 seconds.
# File 178261-7-3-3.wav processed with duration of 4.0 seconds.
# File 178261-7-3-1.wav processed with duration of 4.0 seconds.
# File 74922-4-0-1.wav processed with duration of 4.0 seconds.
# File 118558-5-1-1.wav processed with duration of 4.0 seconds.
# File 162134-7-7-1.wav processed with duration of 4.0 seconds.
# File 157207-6-8-0.wav processed with duration of 4.0 seconds.
# File 83191-9-0-17.wav processed with duration of 4.0 seconds.
# File 101382-2-0-45.wav processed with duration of 4.0 seconds.
# File 69661-3-0-14.wav processed with duration of 4.0 seconds.
# File 208652-8-6-0.wav processed with duration of 4.0 seconds.
# File 28808-1-0-8.wav processed with duration of 4.0 seconds.
# File 85574-3-0-2.wav processed with duration of 4.0 seconds.
# File 189982-0-0-20.wav processed with duration of 4.0 seconds.
# File 93567-8-0-9.wav processed with duration of 4.0 seconds.
# File 188497-2-0-2.wav processed with duration of 4.0 seconds.
# File 172519-9-0-8.wav processed with duration of 4.0 seconds.
# File 200786-5-1-4.wav processed with duration of 4.0 seconds.
# File 164377-9-1-3.wav processed with duration of 4.0 seconds.
# File 142641-3-0-0.wav processed with duration of 4.0 seconds.
# File 100648-1-4-0.wav processed with duration of 4.0 seconds.
# File 195063-4-1-0.wav processed with duration of 4.0 seconds.
# File 117889-9-0-20.wav processed with duration of 4.0 seconds.
# File 165640-4-0-0.wav processed with duration of 4.0 seconds.
# File 83502-0-0-5.wav processed with duration of 4.0 seconds.
# File 187110-2-0-34.wav processed with duration of 4.0 seconds.
# File 102857-5-0-28.wav processed with duration of 4.0 seconds.
# File 167464-0-0-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-12.wav processed with duration of 4.0 seconds.
# File 102857-5-0-8.wav processed with duration of 4.0 seconds.
# File 39847-5-0-8.wav processed with duration of 4.0 seconds.
# File 102857-5-0-14.wav processed with duration of 4.0 seconds.
# File 15544-5-0-3.wav processed with duration of 4.0 seconds.
# File 155262-2-0-15.wav processed with duration of 4.0 seconds.
# File 164377-9-0-16.wav processed with duration of 4.0 seconds.
# File 99192-4-0-20.wav processed with duration of 4.0 seconds.
# File 181624-4-8-0.wav processed with duration of 4.0 seconds.
# File 81791-3-0-1.wav processed with duration of 4.0 seconds.
# File 167464-0-0-23.wav processed with duration of 4.0 seconds.
# File 73524-0-0-8.wav processed with duration of 4.0 seconds.
# File 167464-0-0-22.wav processed with duration of 4.0 seconds.
# File 27070-2-0-7.wav processed with duration of 4.0 seconds.
# File 81791-3-0-0.wav processed with duration of 4.0 seconds.
# File 15544-5-0-2.wav processed with duration of 4.0 seconds.
# File 164194-2-0-26.wav processed with duration of 4.0 seconds.
# File 102857-5-0-15.wav processed with duration of 4.0 seconds.
# File 74364-8-1-13.wav processed with duration of 4.0 seconds.
# File 167464-0-0-1.wav processed with duration of 4.0 seconds.
# File 39847-5-0-9.wav processed with duration of 4.0 seconds.
# File 102857-5-0-9.wav processed with duration of 4.0 seconds.
# File 171478-9-0-55.wav processed with duration of 4.0 seconds.
# File 102857-5-0-29.wav processed with duration of 4.0 seconds.
# File 83502-0-0-4.wav processed with duration of 4.0 seconds.
# File 165640-4-0-1.wav processed with duration of 4.0 seconds.
# File 188813-7-3-0.wav processed with duration of 4.0 seconds.
# File 115241-9-0-6.wav processed with duration of 4.0 seconds.
# File 164377-9-1-43.wav processed with duration of 4.0 seconds.
# File 200786-5-1-5.wav processed with duration of 4.0 seconds.
# File 93567-8-0-8.wav processed with duration of 4.0 seconds.
# File 189982-0-0-35.wav processed with duration of 4.0 seconds.
# File 28808-1-0-9.wav processed with duration of 4.0 seconds.
# File 69661-3-0-29.wav processed with duration of 4.0 seconds.
# File 118558-5-1-0.wav processed with duration of 4.0 seconds.
# File 162134-7-7-0.wav processed with duration of 4.0 seconds.
# File 74922-4-0-0.wav processed with duration of 4.0 seconds.
# File 178261-7-3-0.wav processed with duration of 4.0 seconds.
# File 128470-3-0-8.wav processed with duration of 4.0 seconds.
# File 74364-8-1-3.wav processed with duration of 4.0 seconds.
# File 162134-7-0-1.wav processed with duration of 4.0 seconds.
# File 26255-3-6-0.wav processed with duration of 4.0 seconds.
# File 99192-4-0-3.wav processed with duration of 4.0 seconds.
# File 203424-9-0-15.wav processed with duration of 4.0 seconds.
# File 100648-1-3-0.wav processed with duration of 4.0 seconds.
# File 197554-2-0-74.wav processed with duration of 4.0 seconds.
# File 197554-2-0-60.wav processed with duration of 4.0 seconds.
# File 93567-8-0-17.wav processed with duration of 4.0 seconds.
# File 73524-0-0-101.wav processed with duration of 4.0 seconds.
# File 155241-9-0-88.wav processed with duration of 4.0 seconds.
# File 159742-8-0-8.wav processed with duration of 4.0 seconds.
# File 165166-8-0-1.wav processed with duration of 4.0 seconds.
# File 73524-0-0-30.wav processed with duration of 4.0 seconds.
# File 147491-9-0-0.wav processed with duration of 4.0 seconds.
# File 171478-9-0-26.wav processed with duration of 4.0 seconds.
# File 188497-2-0-17.wav processed with duration of 4.0 seconds.
# File 99192-4-0-52.wav processed with duration of 4.0 seconds.
# File 99192-4-0-47.wav processed with duration of 4.0 seconds.
# File 99192-4-0-53.wav processed with duration of 4.0 seconds.
# File 175842-1-0-0.wav processed with duration of 4.0 seconds.
# File 73524-0-0-31.wav processed with duration of 4.0 seconds.
# File 178826-2-0-12.wav processed with duration of 4.0 seconds.
# File 72538-3-0-4.wav processed with duration of 4.0 seconds.
# File 165166-8-0-0.wav processed with duration of 4.0 seconds.
# File 159742-8-0-9.wav processed with duration of 4.0 seconds.
# File 93567-8-0-16.wav processed with duration of 4.0 seconds.
# File 73524-0-0-114.wav processed with duration of 4.0 seconds.
# File 188813-7-4-0.wav processed with duration of 4.0 seconds.
# File 73524-0-0-128.wav processed with duration of 4.0 seconds.
# File 174289-6-1-0.wav processed with duration of 4.0 seconds.
# File 162134-7-0-0.wav processed with duration of 4.0 seconds.
# File 209672-3-3-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-2.wav processed with duration of 4.0 seconds.
# File 164646-6-0-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-0.wav processed with duration of 4.0 seconds.
# File 163459-3-0-0.wav processed with duration of 4.0 seconds.
# File 99192-4-0-0.wav processed with duration of 4.0 seconds.
# File 101382-2-0-20.wav processed with duration of 4.0 seconds.
# File 162134-7-0-2.wav processed with duration of 4.0 seconds.
# File 180127-4-0-18.wav processed with duration of 4.0 seconds.
# File 14468-3-1-0.wav processed with duration of 4.0 seconds.
# File 189982-0-0-45.wav processed with duration of 4.0 seconds.
# File 174289-6-3-0.wav processed with duration of 4.0 seconds.
# File 162134-7-2-0.wav processed with duration of 4.0 seconds.
# File 20571-3-0-0.wav processed with duration of 4.0 seconds.
# File 136558-9-1-26.wav processed with duration of 4.0 seconds.
# File 51024-3-0-16.wav processed with duration of 4.0 seconds.
# File 93567-8-0-14.wav processed with duration of 4.0 seconds.
# File 165166-8-0-2.wav processed with duration of 4.0 seconds.
# File 178826-2-0-10.wav processed with duration of 4.0 seconds.
# File 83195-9-0-6.wav processed with duration of 4.0 seconds.
# File 188813-7-6-0.wav processed with duration of 4.0 seconds.
# File 84249-9-0-10.wav processed with duration of 4.0 seconds.
# File 155262-2-0-58.wav processed with duration of 4.0 seconds.
# File 128240-3-0-1.wav processed with duration of 4.0 seconds.
# File 84249-9-0-11.wav processed with duration of 4.0 seconds.
# File 84249-9-0-3.wav processed with duration of 4.0 seconds.
# File 14470-2-0-21.wav processed with duration of 4.0 seconds.
# File 73524-0-0-32.wav processed with duration of 4.0 seconds.
# File 83195-9-0-7.wav processed with duration of 4.0 seconds.
# File 200786-5-0-0.wav processed with duration of 4.0 seconds.
# File 202334-9-0-88.wav processed with duration of 4.0 seconds.
# File 115241-9-0-14.wav processed with duration of 4.0 seconds.
# File 165166-8-0-3.wav processed with duration of 4.0 seconds.
# File 178826-2-0-39.wav processed with duration of 4.0 seconds.
# File 93567-8-0-15.wav processed with duration of 4.0 seconds.
# File 14470-2-0-4.wav processed with duration of 4.0 seconds.
# File 202334-9-0-63.wav processed with duration of 4.0 seconds.
# File 147491-9-2-10.wav processed with duration of 4.0 seconds.
# File 189982-0-0-44.wav processed with duration of 4.0 seconds.
# File 180127-4-0-19.wav processed with duration of 4.0 seconds.
# File 17124-1-0-0.wav processed with duration of 4.0 seconds.
# File 99192-4-0-1.wav processed with duration of 4.0 seconds.
# File 101382-2-0-21.wav processed with duration of 4.0 seconds.
# File 74364-8-1-1.wav processed with duration of 4.0 seconds.
# File 100648-1-1-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-5.wav processed with duration of 4.0 seconds.
# File 181624-4-9-0.wav processed with duration of 4.0 seconds.
# File 180127-4-0-21.wav processed with duration of 4.0 seconds.
# File 172519-9-0-10.wav processed with duration of 4.0 seconds.
# File 164377-9-1-36.wav processed with duration of 4.0 seconds.
# File 117889-9-0-40.wav processed with duration of 4.0 seconds.
# File 88121-8-0-2.wav processed with duration of 4.0 seconds.
# File 93567-8-0-11.wav processed with duration of 4.0 seconds.
# File 73524-0-0-113.wav processed with duration of 4.0 seconds.
# File 118558-5-2-3.wav processed with duration of 4.0 seconds.
# File 188497-2-0-11.wav processed with duration of 4.0 seconds.
# File 83195-9-0-3.wav processed with duration of 4.0 seconds.
# File 165166-8-0-7.wav processed with duration of 4.0 seconds.
# File 195063-4-0-0.wav processed with duration of 4.0 seconds.
# File 175850-1-0-0.wav processed with duration of 4.0 seconds.
# File 72538-3-0-3.wav processed with duration of 4.0 seconds.
# File 128240-3-0-42.wav processed with duration of 4.0 seconds.
# File 88121-8-2-0.wav processed with duration of 4.0 seconds.
# File 84249-9-0-7.wav processed with duration of 4.0 seconds.
# File 118558-5-0-1.wav processed with duration of 4.0 seconds.
# File 99192-4-0-40.wav processed with duration of 4.0 seconds.
# File 26255-3-0-0.wav processed with duration of 4.0 seconds.
# File 99192-4-0-54.wav processed with duration of 4.0 seconds.
# File 157207-6-9-0.wav processed with duration of 4.0 seconds.
# File 155262-2-0-48.wav processed with duration of 4.0 seconds.
# File 99192-4-0-55.wav processed with duration of 4.0 seconds.
# File 162134-7-6-0.wav processed with duration of 4.0 seconds.
# File 99192-4-0-41.wav processed with duration of 4.0 seconds.
# File 118558-5-0-0.wav processed with duration of 4.0 seconds.
# File 14468-3-5-0.wav processed with duration of 4.0 seconds.
# File 84249-9-0-6.wav processed with duration of 4.0 seconds.
# File 178261-7-2-0.wav processed with duration of 4.0 seconds.
# File 165166-8-0-6.wav processed with duration of 4.0 seconds.
# File 178826-2-0-28.wav processed with duration of 4.0 seconds.
# File 83195-9-0-2.wav processed with duration of 4.0 seconds.
# File 178826-2-0-14.wav processed with duration of 4.0 seconds.
# File 118558-5-2-2.wav processed with duration of 4.0 seconds.
# File 73524-0-0-23.wav processed with duration of 4.0 seconds.
# File 93567-8-0-10.wav processed with duration of 4.0 seconds.
# File 88121-8-0-3.wav processed with duration of 4.0 seconds.
# File 188813-7-2-0.wav processed with duration of 4.0 seconds.
# File 180127-4-0-20.wav processed with duration of 4.0 seconds.
# File 81791-3-1-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-4.wav processed with duration of 4.0 seconds.
# File 188813-7-0-0.wav processed with duration of 4.0 seconds.
# File 74364-8-1-6.wav processed with duration of 4.0 seconds.
# File 189982-0-0-43.wav processed with duration of 4.0 seconds.
# File 11722-3-0-0.wav processed with duration of 4.0 seconds.
# File 172519-9-0-13.wav processed with duration of 4.0 seconds.
# File 88121-8-0-1.wav processed with duration of 4.0 seconds.
# File 178261-7-0-0.wav processed with duration of 4.0 seconds.
# File 93567-8-0-12.wav processed with duration of 4.0 seconds.
# File 178826-2-0-16.wav processed with duration of 4.0 seconds.
# File 162134-7-4-0.wav processed with duration of 4.0 seconds.
# File 147491-9-0-5.wav processed with duration of 4.0 seconds.
# File 118558-5-2-0.wav processed with duration of 4.0 seconds.
# File 165166-8-0-4.wav processed with duration of 4.0 seconds.
# File 72538-3-0-0.wav processed with duration of 4.0 seconds.
# File 157207-6-10-0.wav processed with duration of 4.0 seconds.
# File 28808-1-0-10.wav processed with duration of 4.0 seconds.
# File 118558-5-0-2.wav processed with duration of 4.0 seconds.
# File 99192-4-0-43.wav processed with duration of 4.0 seconds.
# File 196069-2-0-0.wav processed with duration of 4.0 seconds.
# File 147491-9-2-6.wav processed with duration of 4.0 seconds.
# File 155262-2-0-63.wav processed with duration of 4.0 seconds.
# File 138017-9-0-2.wav processed with duration of 4.0 seconds.
# File 28808-1-0-11.wav processed with duration of 4.0 seconds.
# File 205013-6-0-0.wav processed with duration of 4.0 seconds.
# File 72538-3-0-1.wav processed with duration of 4.0 seconds.
# File 165166-8-0-5.wav processed with duration of 4.0 seconds.
# File 118558-5-2-1.wav processed with duration of 4.0 seconds.
# File 178826-2-0-17.wav processed with duration of 4.0 seconds.
# File 73524-0-0-105.wav processed with duration of 4.0 seconds.
# File 136558-9-1-21.wav processed with duration of 4.0 seconds.
# File 93567-8-0-13.wav processed with duration of 4.0 seconds.
# File 88121-8-0-0.wav processed with duration of 4.0 seconds.
# File 189982-0-0-42.wav processed with duration of 4.0 seconds.
# File 74364-8-1-7.wav processed with duration of 4.0 seconds.
# File 99192-4-0-7.wav processed with duration of 4.0 seconds.
# File 101382-2-0-33.wav processed with duration of 4.0 seconds.

# %% [markdown]
# ##### Checking if there's still audios with duration different than 4 seconds

# %%
# Path to the folder where the audio files are located
base_path = 'UrbanSound8K/audio'

# Expected duration (4 seconds)
expected_duration = 4.0  # in seconds

# Variables to count audio files with correct and incorrect durations
correct_duration_count = 0
incorrect_duration_files = []

# Loop through the 10 folds
for fold in range(1, 11):
    fold_path = os.path.join(base_path, f'fold{fold}')
    
    # Check if the folder path exists
    if os.path.exists(fold_path):
        # Loop through the audio files within the fold
        for file_name in os.listdir(fold_path):
            if file_name.endswith('.wav'):
                # Full path to the audio file
                file_path = os.path.join(fold_path, file_name)
                
                # Load audio using librosa
                audio, sample_rate = librosa.load(file_path)
                duration = len(audio) / sample_rate
                
                # Check if the audio is exactly 4 seconds
                if abs(duration - expected_duration) < 0.01:  # Tolerance of 0.01 seconds
                    correct_duration_count += 1
                else:
                    incorrect_duration_files.append((file_name, duration))

# Display results
print(f"Number of audio files with 4-second duration: {correct_duration_count}")
if incorrect_duration_files:
    print("Audio files with a duration different from 4 seconds:")
    for file_name, duration in incorrect_duration_files:
        print(f"{file_name} - Duration: {duration:.2f} seconds")
else:
    print("All audio files are 4 seconds long.")
# Out:
# Number of audio files with 4-second duration: 8725
# Audio files with a duration different from 4 seconds:
# 36429-2-0-14.wav - Duration: 4.04 seconds
# 36429-2-0-15.wav - Duration: 4.04 seconds
# 36429-2-0-13.wav - Duration: 4.04 seconds
# 36429-2-0-7.wav - Duration: 4.04 seconds
# 36429-2-0-6.wav - Duration: 4.04 seconds
# 36429-2-0-23.wav - Duration: 4.04 seconds
# 36429-2-0-18.wav - Duration: 4.04 seconds

# %% [markdown]
# ##### Okay, we still have files with more than 4 seconds. For that we have a strategy called Trimming.

# %%
# Target duration and sample rate
target_duration = 4.0  # seconds
sample_rate = 22050  # sample rate

# Path to the folder where the audio files are located
base_path = 'UrbanSound8K/audio'

# Loop through the 10 folds
for fold in range(1, 11):
    fold_path = os.path.join(base_path, f'fold{fold}')
    
    # Check if the folder path exists
    if os.path.exists(fold_path):
        print(f"\nProcessing files in {fold_path}...")
        
        # Loop through the audio files within the fold
        for file_name in os.listdir(fold_path):
            if file_name.endswith('.wav'):
                # Full path to the audio file
                file_path = os.path.join(fold_path, file_name)
                
                # Load audio with librosa
                audio, sr = librosa.load(file_path, sr=sample_rate)
                
                # Check if the audio duration is greater than 4 seconds
                if len(audio) > target_duration * sample_rate:
                    # Trim audio to exactly 4 seconds
                    audio = audio[:int(target_duration * sample_rate)]
                    print(f"Trimming {file_name} to {target_duration} seconds.")
                    
                    # Save the trimmed audio, replacing the original file
                    sf.write(file_path, audio, sample_rate)
# Out:
# Processing files in UrbanSound8K/audio/fold1...
#
# Processing files in UrbanSound8K/audio/fold2...
#
# Processing files in UrbanSound8K/audio/fold3...
#
# Processing files in UrbanSound8K/audio/fold4...
#
# Processing files in UrbanSound8K/audio/fold5...
# Trimming 19007-4-0-0.wav to 4.0 seconds.
#
# Processing files in UrbanSound8K/audio/fold6...
#
# Processing files in UrbanSound8K/audio/fold7...
#
# Processing files in UrbanSound8K/audio/fold8...
# Trimming 36429-2-0-14.wav to 4.0 seconds.
# Trimming 36429-2-0-15.wav to 4.0 seconds.
# Trimming 36429-2-0-13.wav to 4.0 seconds.
# Trimming 36429-2-0-7.wav to 4.0 seconds.
# Trimming 36429-2-0-6.wav to 4.0 seconds.
# Trimming 36429-2-0-23.wav to 4.0 seconds.
# Trimming 36429-2-0-18.wav to 4.0 seconds.
#
# Processing files in UrbanSound8K/audio/fold9...
#
# Processing files in UrbanSound8K/audio/fold10...

# %% [markdown]
# ##### Let's see now if all the files have 4 seconds.

# %%
# Path to the folder where the audio files are located
base_path = 'UrbanSound8K/audio'

# Expected duration (4 seconds)
expected_duration = 4.0  # in seconds

# Variables to count audio files with correct and incorrect durations
correct_duration_count = 0
incorrect_duration_files = []

# Loop through the 10 folds
for fold in range(1, 11):
    fold_path = os.path.join(base_path, f'fold{fold}')
    
    # Check if the folder path exists
    if os.path.exists(fold_path):
        # Loop through the audio files within the fold
        for file_name in os.listdir(fold_path):
            if file_name.endswith('.wav'):
                # Full path to the audio file
                file_path = os.path.join(fold_path, file_name)
                
                # Load audio using librosa
                audio, sample_rate = librosa.load(file_path)
                duration = len(audio) / sample_rate
                
                # Check if the audio is exactly 4 seconds
                if abs(duration - expected_duration) < 0.01:  # Tolerance of 0.01 seconds
                    correct_duration_count += 1
                else:
                    incorrect_duration_files.append((file_name, duration))

# Display results
print(f"Number of audio files with 4-second duration: {correct_duration_count}")
if incorrect_duration_files:
    print("Audio files with a duration different from 4 seconds:")
    for file_name, duration in incorrect_duration_files:
        print(f"{file_name} - Duration: {duration:.2f} seconds")
else:
    print("All audio files are 4 seconds long.")
# Out:
# Number of audio files with 4-second duration: 8732
# All audio files are 4 seconds long.

# %% [markdown]
# ##### Great! Now, let's begin the feature extraction.

# %% [markdown]
# ## Feature Extraction <a name="feature-extraction"></a>
# [[go back to the top]](#contents)
#
# As described in [[Notes]](./Notas.md) and in [[PDF]](./Project.pdf), we will need to extract features, and for that we'll use **Mel-Frequency Cepstral Coefficients (MFCCs)** which are well known for their success in environmental sound classification.
#
# We will create a csv to save those features. The provided code returns a set of CSV files, one for each folder (fold) in the dataset, structured as follows:
# - Numerical values of extracted features, including:
#     - Spectral features (e.g., chroma_stft, rms, centroid, bandwidth, rolloff).
#     - Rhythmic features (e.g., tempogram, fourier_tempogram).
#     - Mel-Frequency Cepstral Coefficients (MFCCs 1–25).
#     - Label: The filename of the audio file for identification.
#
# For this feature extraction we will follow the instructions mentioned in the [[Article]](./Research/salamon_urbansound_acmmm14.pdf) and in [[Summary]](./Research/Summary.md), such that:
# - **Frame-Based Analysis**: Audio slices are analyzed per frame, with each frame windowed at **23.2 ms** and a 50% overlap between frames.
#
# - **Frequency Bands**: Computed across **40 Mel bands** from 0 to 22050 Hz.
#
# - **Coefficients**: The first **25 MFCC coefficients** are extracted for each frame to summarize the sound’s spectral properties.

# %%
def extract_features(audio_file, target_duration=4, target_sr=44100):
    # Load audio and define target sample rate
    y, sr = librosa.load(audio_file, sr=target_sr)

    # Normalize amplitude
    y = librosa.util.normalize(y)

    # Define frame parameters
    frame_size = int(target_sr * 0.0232)  # 23.2 ms frame size
    hop_length = frame_size // 2         # 50% overlap

    # Onset envelope
    oenv = librosa.onset.onset_strength(y=y, sr=sr, hop_length=hop_length)

    # Spectral feature list
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=hop_length)
    chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr, hop_length=hop_length)
    melspectogram = librosa.feature.melspectrogram(y=y, sr=sr, hop_length=hop_length, n_mels=40)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=25, hop_length=hop_length)  # First 25 coefficients
    rms = librosa.feature.rms(y=y, hop_length=hop_length)
    centroid = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=hop_length)
    bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr, hop_length=hop_length)
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=hop_length)
    flatness = librosa.feature.spectral_flatness(y=y, hop_length=hop_length)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, hop_length=hop_length)
    crossing_rate = librosa.feature.zero_crossing_rate(y, hop_length=hop_length)

    # Rhythm feature list
    tempogram = librosa.feature.tempogram(onset_envelope=oenv, sr=sr, hop_length=hop_length)
    fourier_tempogram = librosa.feature.fourier_tempogram(onset_envelope=oenv, sr=sr, hop_length=hop_length)

    # Create a dictionary to store the mean value of the features
    features = {
        'chroma_stft': np.mean(chroma_stft),
        'chroma_cens': np.mean(chroma_cens),
        'melspectogram': np.mean(melspectogram),
        'rms': np.mean(rms),
        'centroid': np.mean(centroid),
        'bandwidth': np.mean(bandwidth),
        'contrast': np.mean(contrast),
        'flatness': np.mean(flatness),
        'rolloff': np.mean(rolloff),
        'crossing_rate': np.mean(crossing_rate),
        'tempogram': np.mean(tempogram),
        'fourier_tempogram': np.mean(fourier_tempogram)
    }

    # Add the mean of each of the first 25 MFCC features to the dictionary
    for i in range(1, 26):
        features[f'mfcc_{i}'] = np.mean(mfccs[i - 1])
    return features

def process_data(base_dir):
    for folder in os.listdir(base_dir):
        label_list = []
        features_list = []
        fold_dir = os.path.join(base_dir, folder)
        if os.path.isdir(fold_dir):
            for filename in os.listdir(fold_dir):
                file_path = os.path.join(fold_dir, filename)
                if filename.endswith('.wav'):
                    label = filename
                    features = extract_features(file_path)
                    features_list.append(features)
                    label_list.append(label)

        # Create DataFrame for each folder
        df = pd.DataFrame(features_list)
        df['Label'] = label_list
        # Save DataFrame as a CSV file
        df.to_csv(f'urbansounds_features_{folder}.csv', index=False)
        print(df.head())

def main():
    base_dir = 'UrbanSound8K/audio'
    process_data(base_dir)

if __name__ == '__main__':
    main()
# Out:
# /Users/franciscamihalache/Library/Python/3.9/lib/python/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=384 is too large for input signal of length=346
#   warnings.warn(
# /Users/franciscamihalache/Library/Python/3.9/lib/python/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
#    chroma_stft  chroma_cens  melspectogram       rms     centroid
# 0     0
# 1  1928.368230  23.138114  0.000018  3178.512379       0.046167  ...
# 2  2129.372211  19.816412  0.000012  3473.940458       0.033086  ...
# 3  2938.878411  22.490523  0.000043  8569.281323       0.212662  ...
# 4  1565.142134  22.550517  0.000003  2659.599525       0.031078  ...
#
#      mfcc_17   mfcc_18   mfcc_19    mfcc_20    mfcc_21    mfcc_22    mfcc_23
# 0 -13.838288  7.511040 -1.365896  -3.113962  14.725044 -20.622164  13.100454  \
# 1  -9.643749 -6.173335  4.377084  -6.344460   6.869309  -0.055028   3.869523
# 2  -2.041481 -2.671936 -0.631137  -0.819154  15.073790   2.826488   5.813389
# 3 -11.960629  2.670273  3.988363  -7.785091  10.083614 -12.562323   9.883800
# 4 -11.502039 -7.646056 -7.961185 -11.789680  -2.987048  -8.622738  -3.598621
#
#     mfcc_24   mfcc_25              Label
# 0  4.576317 -6.510311    7965-3-16-0.wav
# 1  1.826995  0.455461   83195-9-0-11.wav
# 2  4.366863 -1.444488   189982-0-0-4.wav
# 3 -2.511369 -1.719058   181624-4-7-0.wav
# 4 -6.149339 -9.078320  159742-8-0-12.wav
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Data Cleaning <a name="data-cleaning"></a>
# [[go back to the top]](#contents)
#
# In this section, we will follow the standard procedures for data cleaning as part of the machine learning project workflow.

# %% [markdown]
# First, let's understand the csvs we've just created.
#
# | **Column**           | **Description**                                                                                 |
# |-----------------------|-----------------------------------------------------------------------------------------------|
# | `chroma_stft`        | Mean value of the Short-Time Fourier Transform (STFT) chroma feature, which captures harmonic intensity by analyzing the signal’s frequency components over short time frames. |
# | `chroma_cens`        | Mean value of the Chroma Energy Normalized Statistics (CENS), a robust version of chroma features emphasizing long-term harmonic content. |
# | `melspectogram`      | Mean value of the Mel spectrogram, representing the signal’s energy distribution across frequencies modeled on human auditory perception. |
# | `rms`                | Mean of the Root Mean Square (RMS) energy, measuring the signal’s average power or amplitude, which can indicate loudness or energy levels. |
# | `centroid`           | Mean spectral centroid, indicating the "brightness" (where higher values indicate brighter sounds with more energy in higher frequencies) of the sound by locating the center of mass of the frequency spectrum. |
# | `bandwidth`          | Mean spectral bandwidth, representing the spread of the spectrum around its centroid, often related to sound timbre. |
# | `contrast`           | Mean spectral contrast, measuring differences between spectral peaks and valleys, useful for identifying tonal and noise-like characteristics. |
# | `flatness`           | Mean spectral flatness, describing how "tonal" (low flatness) or "noisy" (high flatness) a sound is. |
# | `rolloff`            | Mean spectral rolloff frequency, the point below which a specified percentage (e.g., 85%) of the total spectral energy is concentrated, often used to describe tonal characteristics. |
# | `crossing_rate`      | Mean zero-crossing rate, indicating the number of times the signal’s amplitude crosses zero, often related to the sharpness or noisiness of the sound. |
# | `tempogram`          | Mean tempogram, analyzing rhythmic periodicity over time using onset strength, i.e., describes the tempo and rhythmic periodicity of a sound. |
# | `fourier_tempogram`  | Mean Fourier tempogram, a Fourier-transformed version of the tempogram, capturing rhythm and tempo features. |
# | `mcffs_1`            | First Mel-Frequency Cepstral Coefficient (MFCC), summarizing spectral shape and energy for tonal features. |
# | `mcffs_2` to `mcffs_25` | Additional MFCCs (2 through 25), providing detailed frequency characteristics of the audio signal. |
# | `Label`              | Name of the corresponding audio file, serving as a label or identifier. |

# %% [markdown]
# Some **key aspects:**
#
# - **Short-Time Fourier Transform (STFT):** A mathematical tool that splits a signal into small time frames and calculates the frequency components within each frame. The chroma STFT feature focuses on harmonics by mapping frequencies into 12 pitch classes.
#
# - **Chroma Energy Normalized Statistics (CENS):** A variation of chroma features that applies time-averaging and energy normalization to enhance robustness against variations in dynamics and articulation. It is particularly useful for tasks like cover song identification or music similarity analysis, where the emphasis is on harmonic content rather than precise timing or amplitude.

# %% [markdown]
# ### Reading the csvs <a name="reading"></a>
# [[go back to the topic]](#data-cleaning)

# %%
# Reading all 10 CSVs into a list of DataFrames
datasets = [pd.read_csv(f'datasets/urbansounds_features_fold{i}.csv') for i in range(1, 11)]

# %%
for i, df in enumerate(datasets, 1):
    print(f"Here are the first few rows of dataset {i}:")
    print(df.head())
    print("\n" + "-"*50 + "\n")  # Adding a separator line for clarity
# Out:
# Here are the first few rows of dataset 1:
#    chroma_stft  chroma_cens  melspectogram       rms     centroid
# 0     0.350304     0.268477       2.180159  0.109407  2128.781759  \
# 1     0.557573     0.286914       2.055740  0.133274  2698.122148
# 2     0.626652     0.271901       2.807934  0.163664  2191.935651
# 3     0.522626     0.282112       9.592302  0.213379   907.411171
# 4     0.708883     0.236376       4.785410  0.198452  3708.483725
#
#      bandwidth   contrast  flatness      rolloff  crossing_rate  ...
# 0  1878.506128  23.609106  0.000012  4030.692005       0.067559  ...  \
# 1  1501.923366  21.978187  0.000011  4269.424280       0.109128  ...
# 2  2325.010680  20.886596  0.000021  4526.889197       0.050496  ...
# 3  1419.762371  21.135180  0.000006  1371.963766       0.019507  ...
# 4  2723.696499  21.652606  0.000096  6987.088771       0.134702  ...
#
#      mfcc_17    mfcc_18    mfcc_19    mfcc_20    mfcc_21   mfcc_22   mfcc_23
# 0  -7.781542  -5.670235  -1.246437  -6.065276  -0.217272 -5.949829  2.879562  \
# 1   3.490225   1.743056   0.915110   2.841344  -4.322665  1.685505  0.396759
# 2  -1.789076   1.665153  12.567177   0.235710  13.841885  1.748703  1.508938
# 3 -15.207596 -10.465918  -3.916209 -12.101257  -4.019015 -1.538094  1.950449
# 4   2.348586  -0.871024   6.515666  -4.195511   6.029513 -0.336998  2.578580
#
#     mfcc_24   mfcc_25              Label
# 0  4.246119 -1.536338  135776-2-0-49.wav
# 1 -2.697215  4.259012    46654-6-0-0.wav
# 2  3.637871  5.535415   57320-0-0-24.wav
# 3  1.111481 -6.036664  134717-0-0-26.wav
# 4 -0.027295  0.544896   174276-7-5-0.wav
#
# [5 rows x 38 columns]
#
# --------------------------------------------------
#
# Here are the first few rows of dataset 2:
#    chroma_stft  chroma_cens  melspectogram       rms     centroid
# 0     0
# 2 -1.934490  -0.769235  8.416050  -1.439079  9.494238   5.422961   9.381647
# 3  0.433775  -2.307259  6.088287   5.156640  5.281391  -5.421942  11.330167
# 4 -1.724575 -10.143519 -3.146286   1.223832 -9.226150  -7.926032   3.213682
#
#     mfcc_24    mfcc_25              Label
# 0  4.115862 -11.354003  105029-7-1-11.wav
# 1 -2.125484  -7.290719    75743-0-0-6.wav
# 2  7.369273   1.578843    79584-3-0-4.wav
# 3 -3.466592  -2.559209  101729-0-0-21.wav
# 4 -0.407053  -9.763166   159744-8-0-6.wav
#
# [5 rows x 38 columns]
#
# --------------------------------------------------
#
# Here are the first few rows of dataset 10:
#    chroma_stft  chroma_cens  melspectogram       rms     centroid
# 0     0.614504     0.272690       5.286407  0.189217  3629.042860  \
# 1     0.327145     0.246734       9.524182  0.220360  1688.906028
# 2     0.598688     0.278949       5.949107  0.215505  1634.943578
# 3     0.625010     0.280990       1.189542  0.115254  4906.040532
# 4     0.536294     0.258873       6.545214  0.174979  1287.093797
#
#      bandwidth   contrast  flatness      rolloff  crossing_rate  ...
# 0  3904.797842  21.265375  0.000007  9363.333747       0.118665  ...  \
# 1  1928.368230  23.138114  0.000018  3178.512379       0.046167  ...
# 2  2129.372211  19.816412  0.000012  3473.940458       0.033086  ...
# 3  2938.878411  22.490523  0.000043  8569.281323       0.212662  ...
# 4  1565.142134  22.550517  0.000003  2659.599525       0.031078  ...
#
#      mfcc_17   mfcc_18   mfcc_19    mfcc_20    mfcc_21    mfcc_22    mfcc_23
# 0 -13.838288  7.511040 -1.365896  -3.113962  14.725044 -20.622164  13.100454  \
# 1  -9.643749 -6.173335  4.377084  -6.344460   6.869309  -0.055028   3.869523
# 2  -2.041481 -2.671936 -0.631137  -0.819154  15.073790   2.826488   5.813389
# 3 -11.960629  2.670273  3.988363  -7.785091  10.083614 -12.562323   9.883800
# 4 -11.502039 -7.646056 -7.961184 -11.789680  -2.987048  -8.622738  -3.598621
#
#     mfcc_24   mfcc_25              Label
# 0  4.576317 -6.510311    7965-3-16-0.wav
# 1  1.826995  0.455461   83195-9-0-11.wav
# 2  4.366863 -1.444488   189982-0-0-4.wav
# 3 -2.511369 -1.719058   181624-4-7-0.wav
# 4 -6.149339 -9.078320  159742-8-0-12.wav
#
# [5 rows x 38 columns]
#
# --------------------------------------------------

# %% [markdown]
# #### Visualizing the data for a specific audio file

# %% [markdown]
# ##### Waveform plot

# %%
def display_waveform(audio_file, sr=44100):
    """
    Generates and displays the waveform of the given audio file.

    Args:
        audio_file (str): Path to the audio file.
        sr (int): Sampling rate of the audio (default: 44100).
    """
    # Load the audio
    y, sr = librosa.load(audio_file, sr=sr)

    # Plot the waveform
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr)
    plt.title('Waveform')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.tight_layout()
    plt.show()

# Input audio path
input_audio_path = 'UrbanSound8K/audio/fold1/101415-3-0-2.wav'

# Display the waveform
display_waveform(input_audio_path)

# %% [markdown]
# This plot visually represents the audio signal's amplitude over time of a **dog bark**. It shows the raw audio signal in the time domain, with the horizontal axis representing time (in seconds) and the vertical axis representing the amplitude (intensity) of the sound at each point in time.
#
# This plot is useful for understanding the overall structure and duration of the audio, as well as identifying silent or loud regions, transients, or periodic patterns. However, it does not provide detailed information about the frequency content of the audio, which is captured by other features like **spectrograms** or **MFCCs**.

# %% [markdown]
# ##### Mel Spectogram

# %%
def display_spectrogram(audio_file, sr=44100, fmax=8000):
    """
    Generates and displays a mel-frequency spectrogram for the given audio file.

    Args:
        audio_file (str): Path to the audio file.
        sr (int): Sampling rate of the audio (default: 44100).
        fmax (int): Maximum frequency for the mel-frequency spectrogram (default: 8000).
    """
    # Load the audio
    y, sr = librosa.load(audio_file, sr=sr)
    
    # Compute the Mel spectrogram
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)

    # Set up the figure
    fig, ax = plt.subplots(figsize=(10, 4))
    img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=fmax, ax=ax)
    fig.colorbar(img, ax=ax, format='%+2.0f dB')
    ax.set(title='Mel-frequency spectrogram')

    # Display the image in the notebook
    plt.show()

# Input audio path
input_audio_path = 'UrbanSound8K/audio/fold1/101415-3-0-2.wav'

# Generate and display the spectrogram
display_spectrogram(input_audio_path)

# %% [markdown]
# This shows how the energy of audio signals is distributed over frequency and time (as explained above).
#
# The bright areas indicate **higher energy** concentrated at specific frequencies, which is characteristic of a dog bark.
#
# The pattern reveals distinct intervals with bursts of energy and repeating harmonic structures, reflecting the short, sharp, and periodic nature of a typical bark. The onsets and decays visible in the spectrogram align with the rhythmic and energetic nature of dog vocalizations.

# %% [markdown]
# ##### MFCCs

# %%
def display_mfcc(audio_file, sr=44100, n_mfcc=13):
    """
    Generates and displays the MFCCs for the given audio file.

    Args:
        audio_file (str): Path to the audio file.
        sr (int): Sampling rate of the audio (default: 44100).
        n_mfcc (int): Number of MFCCs to extract (default: 13).
    """
    # Load the audio
    y, sr = librosa.load(audio_file, sr=sr)

    # Compute the MFCCs
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)

    # Plot the MFCCs
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='time', sr=sr)
    plt.title(f'MFCCs (n_mfcc={n_mfcc})')
    plt.colorbar()
    plt.tight_layout()
    plt.show()

# Display the MFCCs
display_mfcc(input_audio_path)

# %% [markdown]
# This one displays the first 13 Mel-frequency cepstral coefficients (MFCCs) extracted from the audio, which represent the **spectral characteristics** of the sound over time. These coefficients capture key features of the audio's **timbre and texture**, particularly reflecting the overall shape of the sound's frequency spectrum. The horizontal axis represents time, while the vertical axis corresponds to the 13 MFCCs. Since only the first 13 MFCCs are extracted, the plot focuses on the most significant features of the audio signal, which are crucial for tasks like speech recognition and audio classification.

# %% [markdown]
# ### Cleaning the csvs <a name="cleaning"></a>
# [[go back to the topic]](#data-cleaning)
#
# In this section, we will perform data cleaning. This process will include the following steps:
#
# - Check for Missing Values
# - Check if there are any columns with object type
# - Check for Duplicates
# - Validate Column Data Types
# - Normalization
# - Label Encoding

# %% [markdown]
# ##### Missing values

# %%
def check_missing_values(df):
    missing_values = df.isnull().sum()
    if missing_values.any():
        print(f"  - Missing values detected:\n{missing_values[missing_values > 0]}")
    else:
        print("  - No missing values detected.")

# %% [markdown]
# ##### Columns with object type

# %%
def check_object_columns(df):
    object_columns = df.select_dtypes(include=['object']).columns
    if object_columns.any():
        print(f"  - Columns with object data type: {object_columns.tolist()}")
    else:
        print("  - No columns with object data type detected.")

# %% [markdown]
# ##### Duplicates

# %%
def check_duplicates(df):
    duplicates = df.duplicated().sum()
    if duplicates > 0:
        print(f"  - {duplicates} duplicate rows found.")
        df = df.drop_duplicates()  
    else:
        print("  - No duplicate rows detected.")
    return df  

def drop_duplicates(df):
    duplicates = df.duplicated().sum()
    if duplicates > 0:
        print(f"  - {duplicates} duplicate rows found.")
        df = df.drop_duplicates() 
    else:
        print("  - No duplicate rows detected.")
    return df

# %% [markdown]
# ##### Column Data Types

# %%
def validate_column_data_types(df):
    column_data_types = df.dtypes
    print(f"  - Column data types:\n{column_data_types}")

# %% [markdown]
# ##### Normalization
# We opted for **MinMaxScaler** to normalize the audio features, as it scales the data to a fixed range (0-1), which is advantageous for neural networks. This choice was informed by insights from [this site](https://vitalflux.com/minmaxscaler-standardscaler-python-examples/), which highlights the benefits of using MinMaxScaler over StandardScaler for neural network applications.

# %%
def normalize_data(df):
    # Normalize numerical columns
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    if len(numeric_columns) > 0:
        scaler = MinMaxScaler()
        
        df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
        print(f"Normalized values:\n{df[numeric_columns].describe()}")
        print(f"  - Normalized numeric columns: {numeric_columns.tolist()}")

    if 'Label' in df.columns:
        # Extract the classID from each filename
        df['Label'] = df['Label'].apply(lambda x: int(x.split('-')[1]) if isinstance(x, str) and len(x.split('-')) > 1 else None)
        print(f"Updated 'Label' column to 'classID' values.")
    
    return df

# %% [markdown]
# ##### fourier_tempogram normalization
# Since **fourier_tempogram** didn't normalize, that is, the values of it were extremly high, we decided to do a single normalization function to handle that feature in specific.

# %%
def normalize_fourier_tempogram(df):
    """
    Normalizes the 'fourier_tempogram' column in the DataFrame using MinMaxScaler.
    """
    if 'fourier_tempogram' in df.columns:
        scaler = MinMaxScaler()
        df[['fourier_tempogram']] = scaler.fit_transform(df[['fourier_tempogram']])
        print("  - 'fourier_tempogram' normalized.")
    else:
        print("  - 'fourier_tempogram' column not found. Skipping normalization.")
    return df

# %% [markdown]
# ##### Label Encoding
# The primary reason for this choice was to reduce the dimensionality of the input data.
# We used Label Encoding because neural networks in TensorFlow can process integer labels directly. One-Hot Encoding was unnecessary as it adds memory overhead without improving performance for this task.

# %%
def label_encode_data(df):
    """
    Performs Label Encoding on all object-type columns in the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame.

    Returns:
        df (pd.DataFrame): DataFrame with Label Encoding applied.
    """
    object_columns = df.select_dtypes(include=['object']).columns
    if len(object_columns) > 0:
        for col in object_columns:
            le = LabelEncoder()
            df[col] = le.fit_transform(df[col])
            print(f"  - Label Encoding applied to column: {col}")
    else:
        print("  - No columns found for Label Encoding.")
    return df

# %% [markdown]
# ##### Putting it All Together

# %%
folder_path = "datasets"
file_names = [f"urbansounds_features_fold{i}.csv" for i in range(1, 11)]
file_paths = [os.path.join(folder_path, file_name) for file_name in file_names]

# Iterar sobre os arquivos e processá-los
for i, file_path in enumerate(file_paths, 1):
    print(f"Data cleaning for file: {file_path}")
    
    # Carregar o dataset
    df = pd.read_csv(file_path)
    
    # 1. Check for missing values
    check_missing_values(df)
    
    # 2. Check for object-type columns
    check_object_columns(df)
    
    # 3. Check for duplicates
    df = drop_duplicates(df)
    
    # 4. Validate column data types
    validate_column_data_types(df)
    
    # 5. Normalize numeric columns
    df = normalize_data(df)

    # 6. Apply Label Encoding
    df = label_encode_data(df)

    # 7. Normalize fourier_tempogram
    df = normalize_fourier_tempogram(df)
    
    # Save the cleaned DataFrame to the same file
    df.to_csv(file_path, index=False)
    print(f"  - Cleaned data saved to: {file_path}")
    print("\n" + "-" * 50 + "\n")
# Out:
# Data cleaning for file: datasets\urbansounds_features_fold1.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   873.000000   873.000000     873.000000  873.000000  873.000000
# mean      0.474372     0.833968       0.274488    0.367773    0.274531
# std       0.215143     0.190856       0.214417    0.165944    0.178820
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.330072     0.806550       0.119485    0.258397    0.142317
# 50%       0.516797     0.900788       0.204747    0.369094    0.240769
# 75%       0.641086     0.947758       0.390700    0.468723    0.343151
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  873.000000  873.000000  873.000000  873.000000     873.000000  ...
# mean     0.473289    0.372315    0.002934    0.401846       0.172446  ...
# std      0.219854    0.162473    0.042332    0.221589       0.149674  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.305599    0.276814    0.000049    0.228146       0.074648  ...
# 50%      0.464224    0.344338    0.000113    0.357043       0.129930  ...
# 75%      0.652245    0.425412    0.000218    0.533305       0.214987  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  873.000000  873.000000  873.000000  873.000000  873.000000  873.000000
# mean     0.518134    0.439757    0.419680    0.421556    0.334647    0.395330
# std      0.192782    0.152820    0.120015    0.138898    0.133437    0.119957
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.411434    0.338500    0.357965    0.344389    0.238672    0.335482
# 50%      0.536753    0.444050    0.435082    0.425739    0.314793    0.415049
# 75%      0.641397    0.535912    0.501332    0.506345    0.430218    0.468170
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  873.000000  873.000000  873.000000  873.000000
# mean     0.605314    0.491839    0.443756    0.580191
# std      0.174144    0.145780    0.139943    0.117731
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.477442    0.415716    0.383790    0.503545
# 50%      0.614467    0.492651    0.452147    0.567707
# 75%      0.727046    0.578945    0.536294    0.647909
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold1.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold2.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   888.000000   888.000000     888.000000  888.000000  888.000000
# mean      0.540817     0.830786       0.182900    0.413864    0.271928
# std       0.207352     0.176350       0.147196    0.182551    0.176356
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.405707     0.796860       0.083290    0.293164    0.163408
# 50%       0.565846     0.895877       0.163231    0.420442    0.230323
# 75%       0.670416     0.939621       0.246529    0.523027    0.312865
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  888.000000  888.000000  888.000000  888.000000     888.000000  ...
# mean     0.449813    0.351190    0.010725    0.322899       0.184534  ...
# std      0.185531    0.141668    0.051828    0.199553       0.171601  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.309773    0.273785    0.002027    0.195602       0.080682  ...
# 50%      0.428062    0.331618    0.004109    0.268662       0.139008  ...
# 75%      0.552371    0.414842    0.007472    0.415025       0.209570  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  888.000000  888.000000  888.000000  888.000000  888.000000  888.000000
# mean     0.490678    0.386586    0.327479    0.456629    0.420503    0.423917
# std      0.149002    0.110117    0.103255    0.097989    0.145744    0.134346
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.392753    0.327070    0.263644    0.403292    0.329159    0.342865
# 50%      0.496337    0.393380    0.329154    0.463617    0.417026    0.438845
# 75%      0.573038    0.454286    0.388478    0.515705    0.505160    0.498266
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  888.000000  888.000000  888.000000  888.000000
# mean     0.336238    0.340265    0.490076    0.572425
# std      0.105955    0.130351    0.134540    0.127608
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.265036    0.265896    0.409284    0.514370
# 50%      0.336889    0.336465    0.510987    0.577599
# 75%      0.421022    0.418309    0.579493    0.643825
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold2.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold3.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   925.000000   925.000000     925.000000  925.000000  925.000000
# mean      0.514253     0.827784       0.234995    0.450086    0.395142
# std       0.235480     0.178560       0.152784    0.180842    0.181363
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.345254     0.801895       0.123482    0.323676    0.259888
# 50%       0.548298     0.889191       0.213735    0.478460    0.357103
# 75%       0.670274     0.931579       0.324004    0.567553    0.496604
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  925.000000  925.000000  925.000000  925.000000     925.000000  ...
# mean     0.449818    0.308662    0.001760    0.447278       0.267625  ...
# std      0.205134    0.133256    0.033302    0.220972       0.177837  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.289462    0.221640    0.000108    0.272037       0.165991  ...
# 50%      0.437636    0.290255    0.000236    0.401854       0.219241  ...
# 75%      0.607269    0.357443    0.000451    0.595591       0.319106  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  925.000000  925.000000  925.000000  925.000000  925.000000  925.000000
# mean     0.493840    0.493297    0.364215    0.322955    0.341522    0.360277
# std      0.168444    0.151520    0.152222    0.123150    0.124410    0.122660
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.398145    0.384323    0.278873    0.264051    0.271060    0.286296
# 50%      0.488874    0.478826    0.355661    0.314380    0.319064    0.342851
# 75%      0.606865    0.592107    0.428667    0.357670    0.388315    0.413638
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  925.000000  925.000000  925.000000  925.000000
# mean     0.384915    0.487239    0.421369    0.535925
# std      0.093272    0.140267    0.118488    0.094235
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.328821    0.409999    0.363210    0.489345
# 50%      0.376417    0.483047    0.432987    0.537289
# 75%      0.442116    0.584939    0.488590    0.598200
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold3.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold4.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   990.000000   990.000000     990.000000  990.000000  990.000000
# mean      0.514378     0.852818       0.110897    0.308235    0.323358
# std       0.209138     0.162073       0.094766    0.135339    0.173436
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.348179     0.820774       0.053356    0.222277    0.215817
# 50%       0.533062     0.908732       0.097637    0.320725    0.287531
# 75%       0.692382     0.948377       0.144442    0.388310    0.406410
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  990.000000  990.000000  990.000000  990.000000     990.000000  ...
# mean     0.541653    0.408202    0.003781    0.427064       0.207764  ...
# std      0.222684    0.122119    0.057424    0.220479       0.149683  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.389312    0.332711    0.000011    0.261260       0.111738  ...
# 50%      0.529954    0.387018    0.000022    0.404917       0.161870  ...
# 75%      0.726950    0.472153    0.000043    0.590117       0.251558  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.385984    0.348694    0.340416    0.337060    0.389491    0.501010
# std      0.102058    0.108156    0.078975    0.109806    0.150184    0.158565
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.326921    0.288131    0.295715    0.273902    0.299522    0.407249
# 50%      0.391492    0.348132    0.344516    0.329220    0.381738    0.496340
# 75%      0.449408    0.417886    0.381661    0.404846    0.467554    0.597243
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  990.000000  990.000000  990.000000  990.000000
# mean     0.547062    0.394331    0.448879    0.459163
# std      0.108069    0.134151    0.144796    0.101808
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.474501    0.300865    0.366597    0.398828
# 50%      0.547980    0.392017    0.454921    0.458970
# 75%      0.607245    0.484989    0.529712    0.515961
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold4.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold5.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   936.000000   936.000000     936.000000  936.000000  936.000000
# mean      0.517154     0.843758       0.097530    0.291048    0.376601
# std       0.213201     0.155013       0.093747    0.136037    0.215410
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.358434     0.818342       0.037225    0.189744    0.225665
# 50%       0.529804     0.899561       0.083732    0.300792    0.324974
# 75%       0.694640     0.933928       0.128936    0.371062    0.495665
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  936.000000  936.000000  936.000000  936.000000     936.000000  ...
# mean     0.499804    0.347065    0.001532    0.441151       0.197210  ...
# std      0.196325    0.142252    0.033162    0.234358       0.150821  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.351183    0.256460    0.000038    0.263364       0.097945  ...
# 50%      0.475390    0.337272    0.000084    0.389075       0.157151  ...
# 75%      0.653187    0.411590    0.000172    0.632334       0.274247  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean     0.461954    0.381834    0.603242    0.607635    0.600645    0.403298
# std      0.161920    0.145819    0.120176    0.113173    0.145687    0.134236
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.354221    0.287298    0.538775    0.544760    0.502642    0.316720
# 50%      0.450933    0.384259    0.614195    0.617820    0.594036    0.397723
# 75%      0.587200    0.483034    0.675679    0.671856    0.699169    0.501156
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  936.000000  936.000000  936.000000  936.000000
# mean     0.485574    0.602869    0.394945    0.484076
# std      0.159761    0.112785    0.100619    0.101334
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.397893    0.527360    0.328346    0.421447
# 50%      0.479060    0.610288    0.391630    0.490236
# 75%      0.592557    0.672419    0.460373    0.550907
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold5.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold6.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   823.000000   823.000000     823.000000  823.000000  823.000000
# mean      0.505331     0.835739       0.097444    0.283278    0.291895
# std       0.209401     0.167568       0.096651    0.140203    0.174810
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.363459     0.791192       0.037633    0.185361    0.176562
# 50%       0.523565     0.902253       0.072923    0.274666    0.253364
# 75%       0.660869     0.940583       0.132414    0.359931    0.357472
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  823.000000  823.000000  823.000000  823.000000     823.000000  ...
# mean     0.493031    0.327360    0.065959    0.379795       0.186261  ...
# std      0.214004    0.145681    0.083790    0.204020       0.154146  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.352591    0.215622    0.019430    0.223646       0.098130  ...
# 50%      0.479368    0.295424    0.042148    0.332683       0.141649  ...
# 75%      0.647422    0.407346    0.077718    0.485549       0.208847  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  823.000000  823.000000  823.000000  823.000000  823.000000  823.000000
# mean     0.481089    0.508700    0.474914    0.488852    0.550405    0.501519
# std      0.168713    0.148495    0.138980    0.108210    0.134061    0.132048
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.347248    0.425917    0.385386    0.425171    0.469267    0.416443
# 50%      0.473634    0.509794    0.478333    0.491186    0.550782    0.514859
# 75%      0.598002    0.599204    0.566193    0.561115    0.630328    0.597482
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  823.000000  823.000000  823.000000  823.000000
# mean     0.481232    0.453938    0.385424    0.470181
# std      0.137988    0.150111    0.136383    0.101045
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.398334    0.358604    0.301696    0.413538
# 50%      0.479692    0.466626    0.386128    0.470630
# 75%      0.557564    0.545873    0.466306    0.531169
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold6.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold7.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   838.000000   838.000000     838.000000  838.000000  838.000000
# mean      0.502508     0.846898       0.147325    0.237767    0.245827
# std       0.184477     0.131557       0.100657    0.112494    0.173143
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.365411     0.801248       0.072466    0.170684    0.120678
# 50%       0.556290     0.885160       0.137027    0.250260    0.211522
# 75%       0.633032     0.931248       0.201278    0.304960    0.310297
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  838.000000  838.000000  838.000000  838.000000     838.000000  ...
# mean     0.377152    0.230914    0.004532    0.298716       0.185268  ...
# std      0.137083    0.108740    0.063924    0.194099       0.149078  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.277792    0.156103    0.000024    0.138379       0.091874  ...
# 50%      0.365828    0.216496    0.000049    0.258712       0.143501  ...
# 75%      0.477666    0.274672    0.000098    0.432047       0.218853  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  838.000000  838.000000  838.000000  838.000000  838.000000  838.000000
# mean     0.499915    0.579596    0.530041    0.394353    0.339724    0.243299
# std      0.156937    0.145987    0.132441    0.135277    0.107171    0.080286
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.416670    0.483287    0.462394    0.314802    0.271331    0.199789
# 50%      0.498928    0.588329    0.525139    0.400275    0.338706    0.245347
# 75%      0.588137    0.676181    0.610955    0.477998    0.412716    0.285693
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  838.000000  838.000000  838.000000  838.000000
# mean     0.340836    0.546700    0.565744    0.670007
# std      0.090187    0.100838    0.097314    0.083924
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.289958    0.486320    0.517143    0.632234
# 50%      0.340915    0.549080    0.569160    0.668818
# 75%      0.392768    0.605973    0.626547    0.712662
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold7.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold8.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   806.000000   806.000000     806.000000  806.000000  806.000000
# mean      0.590784     0.800191       0.242846    0.432098    0.285108
# std       0.206982     0.199209       0.193548    0.207809    0.197856
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.452288     0.753642       0.095022    0.272974    0.135285
# 50%       0.611446     0.887191       0.182178    0.429374    0.238465
# 75%       0.741967     0.930499       0.330347    0.561120    0.362684
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  806.000000  806.000000  806.000000  806.000000     806.000000  ...
# mean     0.504479    0.230370    0.002224    0.376536       0.218371  ...
# std      0.190612    0.115329    0.042876    0.238373       0.206623  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.366586    0.157423    0.000029    0.185697       0.083117  ...
# 50%      0.473172    0.214110    0.000059    0.325908       0.159855  ...
# 75%      0.652544    0.286564    0.000105    0.544576       0.245884  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  806.000000  806.000000  806.000000  806.000000  806.000000  806.000000
# mean     0.587019    0.404171    0.405195    0.333212    0.280807    0.323955
# std      0.143819    0.167297    0.114854    0.106740    0.099554    0.091788
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.518310    0.290037    0.338963    0.276605    0.228179    0.268977
# 50%      0.593503    0.393765    0.410873    0.330081    0.272088    0.324694
# 75%      0.668987    0.542041    0.470691    0.389712    0.328447    0.381930
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  806.000000  806.000000  806.000000  806.000000
# mean     0.308104    0.481683    0.385299    0.655143
# std      0.119066    0.136197    0.110628    0.089850
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.226639    0.389270    0.321701    0.608680
# 50%      0.296856    0.485376    0.397915    0.655203
# 75%      0.380119    0.574050    0.455752    0.710234
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold8.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold9.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   816.000000   816.000000     816.000000  816.000000  816.000000
# mean      0.505662     0.853344       0.143449    0.360146    0.312220
# std       0.197108     0.156982       0.143777    0.205735    0.202247
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.381443     0.838614       0.037069    0.200876    0.163200
# 50%       0.521000     0.906433       0.094270    0.324860    0.265698
# 75%       0.631894     0.939872       0.192557    0.489189    0.401229
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  816.000000  816.000000  816.000000  816.000000     816.000000  ...
# mean     0.392797    0.283081    0.001462    0.413000       0.269117  ...
# std      0.179743    0.129970    0.035020    0.233957       0.228202  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.251711    0.204797    0.000046    0.230394       0.110477  ...
# 50%      0.405697    0.267464    0.000092    0.364144       0.200901  ...
# 75%      0.532930    0.326238    0.000195    0.593924       0.325401  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  816.000000  816.000000  816.000000  816.000000  816.000000  816.000000
# mean     0.495383    0.504481    0.490455    0.387383    0.338391    0.377988
# std      0.158967    0.144109    0.118262    0.121804    0.138003    0.115727
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.395624    0.412945    0.421111    0.307679    0.242294    0.320007
# 50%      0.507165    0.517655    0.491729    0.382781    0.337033    0.375583
# 75%      0.590724    0.590847    0.572193    0.471532    0.417465    0.441453
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  816.000000  816.000000  816.000000  816.000000
# mean     0.285879    0.315300    0.424902    0.668259
# std      0.129392    0.116879    0.113376    0.103824
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.227624    0.229048    0.365152    0.614031
# 50%      0.285369    0.300370    0.413780    0.673709
# 75%      0.357824    0.367516    0.493464    0.715620
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold9.csv
#
# --------------------------------------------------
#
# Data cleaning for file: datasets\urbansounds_features_fold10.csv
#   - No missing values detected.
#   - Columns with object data type: ['fourier_tempogram', 'Label']
#   - No duplicate rows detected.
#   - Column data types:
# chroma_stft          float64
# chroma_cens          float64
# melspectogram        float64
# rms                  float64
# centroid             float64
# bandwidth            float64
# contrast             float64
# flatness             float64
# rolloff              float64
# crossing_rate        float64
# tempogram            float64
# fourier_tempogram     object
# mfcc_1               float64
# mfcc_2               float64
# mfcc_3               float64
# mfcc_4               float64
# mfcc_5               float64
# mfcc_6               float64
# mfcc_7               float64
# mfcc_8               float64
# mfcc_9               float64
# mfcc_10              float64
# mfcc_11              float64
# mfcc_12              float64
# mfcc_13              float64
# mfcc_14              float64
# mfcc_15              float64
# mfcc_16              float64
# mfcc_17              float64
# mfcc_18              float64
# mfcc_19              float64
# mfcc_20              float64
# mfcc_21              float64
# mfcc_22              float64
# mfcc_23              float64
# mfcc_24              float64
# mfcc_25              float64
# Label                 object
# dtype: object
# Normalized values:
#        chroma_stft  chroma_cens  melspectogram         rms    centroid  \
# count   837.000000   837.000000     837.000000  837.000000  837.000000
# mean      0.574225     0.828027       0.151036    0.339639    0.301615
# std       0.219094     0.149939       0.129728    0.175019    0.201667
# min       0.000000     0.000000       0.000000    0.000000    0.000000
# 25%       0.388243     0.783026       0.057624    0.221315    0.156341
# 50%       0.583843     0.882749       0.115497    0.316437    0.243186
# 75%       0.763985     0.923059       0.207124    0.447964    0.382567
# max       1.000000     1.000000       1.000000    1.000000    1.000000
#
#         bandwidth    contrast    flatness     rolloff  crossing_rate  ...  \
# count  837.000000  837.000000  837.000000  837.000000     837.000000  ...
# mean     0.453445    0.250862    0.005638    0.405543       0.227573  ...
# std      0.157268    0.099999    0.039938    0.226015       0.203359  ...
# min      0.000000    0.000000    0.000000    0.000000       0.000000  ...
# 25%      0.345961    0.190894    0.001226    0.247669       0.090483  ...
# 50%      0.439265    0.236756    0.002524    0.333422       0.162970  ...
# 75%      0.570758    0.294291    0.004444    0.569635       0.279510  ...
# max      1.000000    1.000000    1.000000    1.000000       1.000000  ...
#
#           mfcc_16     mfcc_17     mfcc_18     mfcc_19     mfcc_20     mfcc_21  \
# count  837.000000  837.000000  837.000000  837.000000  837.000000  837.000000
# mean     0.661630    0.323604    0.492677    0.508477    0.381774    0.390778
# std      0.137761    0.110318    0.103954    0.114387    0.131479    0.108189
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.590454    0.257821    0.434019    0.448440    0.290381    0.331645
# 50%      0.668637    0.326633    0.495186    0.512222    0.374925    0.396481
# 75%      0.749949    0.383366    0.555736    0.574211    0.476829    0.461351
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           mfcc_22     mfcc_23     mfcc_24     mfcc_25
# count  837.000000  837.000000  837.000000  837.000000
# mean     0.345061    0.453379    0.360709    0.311358
# std      0.092682    0.133592    0.106582    0.077566
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.281104    0.362837    0.296660    0.264402
# 50%      0.337909    0.455179    0.353576    0.303176
# 75%      0.408469    0.530861    0.426779    0.346761
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 36 columns]
#   - Normalized numeric columns: ['chroma_stft', 'chroma_cens', 'melspectogram', 'rms', 'centroid', 'bandwidth', 'contrast', 'flatness', 'rolloff', 'crossing_rate', 'tempogram', 'mfcc_1', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_6', 'mfcc_7', 'mfcc_8', 'mfcc_9', 'mfcc_10', 'mfcc_11', 'mfcc_12', 'mfcc_13', 'mfcc_14', 'mfcc_15', 'mfcc_16', 'mfcc_17', 'mfcc_18', 'mfcc_19', 'mfcc_20', 'mfcc_21', 'mfcc_22', 'mfcc_23', 'mfcc_24', 'mfcc_25']
# Updated 'Label' column to 'classID' values.
#   - Label Encoding applied to column: fourier_tempogram
#   - 'fourier_tempogram' normalized.
#   - Cleaned data saved to: datasets\urbansounds_features_fold10.csv
#
# --------------------------------------------------

# %% [markdown]
# Since we are done with all the data understanding and preparation, we are now ready to begin the implementation of our chosen models.
#
# From now on, we will continue with the project in **two different notebooks**. The teacher can access the [[MLP]](./MLP.ipynb) file, in which will document the procedure and implementation for the **MLP classifier**, while the [[CNN]](./MLP.ipynb) file will focus on the **CNN classifier**. This separation ensures clarity and makes it easier for the teacher to follow each classifier's workflow individually.
